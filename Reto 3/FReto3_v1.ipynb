# %% [markdown]
# <a href="https://colab.research.google.com/github/andresenrique08/ML_2020/blob/master/Reto%203/FReto3_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reto 3.0
#
# ### Curso de Machine Learning 2020-20
# Autores:
# *    Andrés Enrique Ávila Rojas (201319127)
# *   Jeison Alexander Timana Rangel (201617870)

# %%
# Import libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Modulos para contingencias
from scipy.stats import chi2
from scipy.stats import chi2_contingency

# Modulos de scikit-learn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.exceptions import ConvergenceWarning

# %% [markdown]
# Se toman los datos del repositorio de github con el siguiente link https://raw.githubusercontent.com/andresenrique08/ML_2020/master/Reto%203/msd_genre_dataset.txt

# %%
# Reading file from github
url = "https://raw.githubusercontent.com/andresenrique08/ML_2020/master/Reto%203/msd_genre_dataset.txt"
data  = pd.read_csv(url,skiprows=9, sep=",") 
data.head()
# Out:
#                  %genre            track_id  ... var_timbre11 var_timbre12
# 0  classic pop and rock  TRFCOOU128F427AEC0  ...   181.938688   151.508011
# 1  classic pop and rock  TRNJTPB128F427AE9F  ...   197.933757   251.577525
# 2  classic pop and rock  TRLFJHA128F427AEEA  ...   447.097987   251.880724
# 3  classic pop and rock  TRCQZAG128F427DB97  ...    85.282462   339.897173
# 4  classic pop and rock  TRNXMNM128F427DB8C  ...    81.061326   208.355152
#
# [5 rows x 34 columns]

# %% [markdown]
# Los géneros presentes en la base de datos son los siguientes:

# %%
generos = data['%genre'].unique()
generos = pd.DataFrame(data=generos, columns=['Generos'])
generos
# Out:
#                  Generos
# 0   classic pop and rock
# 1                   punk
# 2                   folk
# 3                    pop
# 4  dance and electronica
# 5                  metal
# 6         jazz and blues
# 7              classical
# 8                hip-hop
# 9        soul and reggae

# %% [markdown]
# ## Preparación de los datos
#
# Teniendo en cuenta que se espera resolver el problema de clasificación binaria (usando ```scikit-learn```) entre los géneros jazz and blues y soul and reggae, se procede a crear un dataframe con solo la información correspondiente a estos dos géneros.

# %%
data_bin = data[data['%genre'].isin(['jazz and blues','soul and reggae'])]
data_bin.head()
# Out:
#                %genre            track_id  ... var_timbre11 var_timbre12
# 48942  jazz and blues  TRJBLUX12903CE16EC  ...   261.850703   240.834177
# 48943  jazz and blues  TRDPDLX12903CE16F2  ...   261.643570   332.356536
# 48944  jazz and blues  TRMWVBM128F42374DA  ...   481.149049   442.663136
# 48945  jazz and blues  TRMLIWL128F42374DE  ...   250.545027   348.842236
# 48946  jazz and blues  TRGFUVB128F42374E1  ...   262.670577   272.634634
#
# [5 rows x 34 columns]

# %% [markdown]
# Para asegurarnos que solo estén los generos que se usarán para el análisis, se verifica que solo estos géneros esten en nuestro nuevo dataframe

# %%
generos = data_bin['%genre'].unique()
generos = pd.DataFrame(data=generos, columns=['Generos'])
generos
# Out:
#            Generos
# 0   jazz and blues
# 1  soul and reggae

# %% [markdown]
# Ahora comparamos cuantos datos de cada género hay en nuestro dataframe, obteniendo el siguiente histograma

# %%
f = plt.figure()
sns.countplot(x="%genre", data=data_bin, palette="Set1")
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.title('Histograma de los datos')
plt.show()
data_bin['%genre'].value_counts()/len(data_bin)
# Out:
# jazz and blues     0.519042
# soul and reggae    0.480958
# Name: %genre, dtype: float64

# %% [markdown]
# En esta oportunidad no se tendrá en cuenta la columna correspondiente a ```artist_name``` debido a que este dato puede generar un error en el modelamiento del clasificador afectando los resultados de predicción, considerando que esta variable provee información adicional que facilita su clasificación. Con esto en mente, se obtiene la siguiente información.

# %%
data_bin = data_bin.drop(['artist_name'],axis=1)
data_bin.head()
# Out:
#                %genre            track_id  ... var_timbre11  var_timbre12
# 48942  jazz and blues  TRJBLUX12903CE16EC  ...   261.850703    240.834177
# 48943  jazz and blues  TRDPDLX12903CE16F2  ...   261.643570    332.356536
# 48944  jazz and blues  TRMWVBM128F42374DA  ...   481.149049    442.663136
# 48945  jazz and blues  TRMLIWL128F42374DE  ...   250.545027    348.842236
# 48946  jazz and blues  TRGFUVB128F42374E1  ...   262.670577    272.634634
#
# [5 rows x 33 columns]

# %% [markdown]
# Continuando con el pre procesamiento de los datos, pasaremos a verificar los datos nulos dentro del dataframe

# %%
missing_values_count = data_bin.isnull().sum()
total_missing = missing_values_count.sum()
print('Hay {} datos perdidos en el dataframe'.format(total_missing))
# Out:
# Hay 0 datos perdidos en el dataframe

# %% [markdown]
# Se observa que no hay datos perdidos. Ahora, se procede a verificar si hay filas duplicadas.

# %%
print('Hay {} filas duplicadas en el dataframe'.format(data_bin.duplicated().sum()))
# Out:
# Hay 0 filas duplicadas en el dataframe

# %% [markdown]
# Una vez observado que no hay filas duplicadas ni datos perdidos, se procede a verificar el tipo de las variables del dataframe.

# %%
data_bin.dtypes
# Out:
# %genre             object
# track_id           object
# title              object
# loudness          float64
# tempo             float64
# time_signature      int64
# key                 int64
# mode                int64
# duration          float64
# avg_timbre1       float64
# avg_timbre2       float64
# avg_timbre3       float64
# avg_timbre4       float64
# avg_timbre5       float64
# avg_timbre6       float64
# avg_timbre7       float64
# avg_timbre8       float64
# avg_timbre9       float64
# avg_timbre10      float64
# avg_timbre11      float64
# avg_timbre12      float64
# var_timbre1       float64
# var_timbre2       float64
# var_timbre3       float64
# var_timbre4       float64
# var_timbre5       float64
# var_timbre6       float64
# var_timbre7       float64
# var_timbre8       float64
# var_timbre9       float64
# var_timbre10      float64
# var_timbre11      float64
# var_timbre12      float64
# dtype: object

# %% [markdown]
# Se puede observar que hay 3 variables categoricas y todas las demás son númericas. Una de las variables categoricas corresponde a la variable ```%genre```, la cual es nuestra variable objetivo por lo tanto es necesario ver el comportamiento de las otras variables para conocer si pueden o no influir el modelo de clasificación. Para ello procederemos a verficar el total de valores únicos y compararlos con la longitud total de los datos del dataframe, de la siguiente forma.

# %%
total_data = len(data_bin)
tot_track_id = len(data_bin.track_id.unique())
tot_title= len(data_bin.title.unique())

if total_data == tot_track_id:
  print('Los valores únicos de la variable track_id son iguales al total de datos, por lo que no aportan información relevante. \n')
else:
  print('La variable track_id puede aportar información útil para el análisis y se debe revisar en detalle. \n')

if total_data == tot_title:
  print('Los valores únicos de la variable title son iguales al total de datos, por lo que no aportan información relevante.')
else:
  print('La variable title puede aportar información útil para el análisis y se debe revisar en detalle.')
# Out:
# Los valores únicos de la variable track_id son iguales al total de datos, por lo que no aportan información relevante.
#
# La variable title puede aportar información útil para el análisis y se debe revisar en detalle.

# %% [markdown]
# Se observa que la variable ```track_id``` puede ser eliminada del modelo, puesto que no aporta información relavante para la clasificación y hay un track_id diferente para cada fila. Por su parte la variable ```title``` no contiene un valor diferente por cada fila, lo que muestra que algunos de los títulos de las canciones se repiten, esto puede deberse a que diferentes autores nombraron de igual forma algunas canciones o debido a otros factores. Para comprobar que la variable objetivo ```%genre``` no tenga dependencia de esta variable, se realiza un análisis de contingencia con chi-cuadrado como se muestra a continuación.

# %%
Tabla_c = pd.crosstab(index=data_bin['%genre'],columns=data_bin["title"],margins=True)
chi2_contingency(Tabla_c)
# Out:
# (8183.224779508331,
#  1.0,
#  14690,
#  array([[5.19041916e-01, 5.19041916e-01, 5.19041916e-01, ...,
#          5.19041916e-01, 5.19041916e-01, 4.33400000e+03],
#         [4.80958084e-01, 4.80958084e-01, 4.80958084e-01, ...,
#          4.80958084e-01, 4.80958084e-01, 4.01600000e+03],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#          1.00000000e+00, 1.00000000e+00, 8.35000000e+03]]))

# %%
# Guardo el p-value en una variable para luego evaluarla dado las condiciones de abajo
pvalue = chi2_contingency(Tabla_c)[1]
# Usando prints y if para saber si acepto o no la hipotesis nula y 
# asi concentrarme en el analisis 
print("Hipotesis NULA:", "Las variables son independendientes")
print("P-Value:", pvalue)

pval = pvalue
# nivel de significancia 0.001
if pval > 0.001:
    print("Accept NULL hypothesis - Las variables son independientes es decir que no tienen relación entre ellas.")
if pval <= 0.001:
    print("Reject NULL hypothesis - Las variables son dependientes.")
# Out:
# Hipotesis NULA: Las variables son independendientes
# P-Value: 1.0
# Accept NULL hypothesis - Las variables son independientes es decir que no tienen relación entre ellas.

# %% [markdown]
# Los resultados muestran bajo un nivel de significancia del 0.001% que las variables no tienen dependencia entre ellas. Por lo que la variable ```title``` podría ser eliminada del modelo. De esta forma se obtiene el siguiente conjunto de datos para la implementación del modelo.

# %%
data_bin = data_bin.drop(['track_id','title'], axis=1)
data_bin.head()
# Out:
#                %genre  loudness  ...  var_timbre11  var_timbre12
# 48942  jazz and blues   -18.996  ...    261.850703    240.834177
# 48943  jazz and blues   -19.347  ...    261.643570    332.356536
# 48944  jazz and blues    -9.472  ...    481.149049    442.663136
# 48945  jazz and blues   -14.406  ...    250.545027    348.842236
# 48946  jazz and blues    -9.289  ...    262.670577    272.634634
#
# [5 rows x 31 columns]

# %% [markdown]
# De esta manera observamos que la única variable categorica dentro del dataframe es la variable objetivo. Como sabemos esta variable es binaria, por lo que se reemplazará los valores categoricos de la siguiente manera:
#
#
# *   ```jazz and blues``` = 0
# *   ```soul and reggae``` = 1
#
# Obteniendo finalmente el siguiente dataframe.

# %%
data_bin['%genre'].replace(['jazz and blues','soul and reggae'],[0,1], inplace=True)
data_bin.head()
# Out:
#        %genre  loudness    tempo  ...  var_timbre10  var_timbre11  var_timbre12
# 48942       0   -18.996   89.147  ...    233.206167    261.850703    240.834177
# 48943       0   -19.347  125.825  ...    227.275123    261.643570    332.356536
# 48944       0    -9.472  121.707  ...    549.493210    481.149049    442.663136
# 48945       0   -14.406   83.012  ...    278.578591    250.545027    348.842236
# 48946       0    -9.289   76.013  ...    403.532772    262.670577    272.634634
#
# [5 rows x 31 columns]

# %% [markdown]
# Adicionalmente, siguiendo las recomendaciones de la página oficinal de los <a href="https://scikit-learn.org/stable/modules/neural_networks_supervised.html#mlp-tips">modelos de redes neuronales (supervisado)</a> de Scikit-Learn, se realiza la estandarización del conjunto de datos mediante el método MinMaxScaler que estandariza los datos $x$ de la siguiente forma, teniendo en cuenta los datos de la columna de la variable $v$:
#
# $ z=\frac{x-\min(x)}{\max(x)-\min(x)}[(\max(v)-\min(v))+\min(x)]$
#
# Donde $v$ pertenece al conjunto total de $x$ y $x$ pasa por un $v$ especifico, es decir por cada variable representada por una columna. De esta manera se obtiene la siguiente muestra de los datos.

# %%
scaler = MinMaxScaler()
data_bin = pd.DataFrame(scaler.fit_transform(data_bin), columns=data_bin.columns)
data_bin['%genre'] = data_bin['%genre'].astype(int)
data_bin.head()
# Out:
#    %genre  loudness     tempo  ...  var_timbre10  var_timbre11  var_timbre12
# 0       0  0.540775  0.353277  ...      0.095678      0.106249      0.086422
# 1       0  0.532164  0.498627  ...      0.092242      0.106146      0.124834
# 2       0  0.774436  0.482308  ...      0.278903      0.215859      0.171129
# 3       0  0.653386  0.328965  ...      0.121962      0.100599      0.131753
# 4       0  0.778925  0.301229  ...      0.194348      0.106659      0.099769
#
# [5 rows x 31 columns]

# %% [markdown]
# Ahora, con el fin de validar las correlaciones entre las variables se presentan los siguientes mapas de calor de las correlaciones de pearson y spearman.

# %%
fig = plt.figure(figsize =(15,18))
plt.subplot(2,1,1)
sns.heatmap(data_bin.corr(method ='pearson'))
plt.title(r'$\bf{Pearson}$')
plt.subplot(2,1,2)
sns.heatmap(data_bin.corr(method ='spearman'))
plt.title(r'$\bf{Spearman}$')
fig.suptitle('Mapa de calor para las correlaciones de los datos', y=0.91, fontsize=16)
# Out:
# Text(0.5, 0.91, 'Mapa de calor para las correlaciones de los datos')

# %% [markdown]
# Se puede observar que la mayoría de variable tiene una correlación por encima de 0.5 con la variable objetivo y que las variables que no tienen una correlación significativa con la variable objetivo, tienen relación con otras variables por lo que se posdría considerar que todas las variables terminarán teniendo algún grado de influencia en el resultado de clasificación final. Por ello se decide dejar la base de datos que está hasta este punto.

# %% [markdown]
# ### Selección del conjunto de entrenamiento y de prueba
#
# En este punto se selecciona el conjunto de datos de entrenamiento y de prueba para el modelo de clasificación que se realizará. En esta ocasión se usa la función ```train_test_split```, donde se define que el 20% de los datos totales disponibles para el análisis son destinados para el conjunto de evaluación o validación del modelo, lo que implica que este conjunto tendrá un total de 1670 datos; mientras que el conjunto de entrenamiento tendrá el resto de datos, es decir 6680 datos. Este proceso es presentado a continuación:

# %%
Y = data_bin['%genre']
X = data_bin.drop(['%genre'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Con el fin de observar el total de datos de cada género que están siendo usados para cada conjunto se presentan los siguientes histogramas.

# %%
fig = plt.figure()
data_bin['%genre'].hist(label='Complete Data')
y_train.hist(label='Train Data')
y_test.hist(label='Test Data')
plt.legend()
plt.grid(linestyle='--',b=True, which='major')
plt.ylabel('Frecuencia absoluta')
plt.title('Histograma de conjuntos de entrenamiento y test', fontsize=14)
plt.show()
print('jazz and blues: 0 \nsoul and reggae: 1')
# Out:
# jazz and blues: 0
# soul and reggae: 1

# %% [markdown]
# Adicionalmente, se separa el conjunto de datos de entrenamiento para poder realizar el entrenamiento y validación de redes dentro de las capas escondidas de cada percentrón multinivel a implementar. De esta manera se obtienen los siguientes conjuntos.

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_train, y_train, test_size = 0.2, random_state = 0)

fig = plt.figure()
y_train.hist(label='Train Data')
y_train1.hist(label='Train set in Train Data')
y_test1.hist(label='Test set in Train Data')
plt.legend()
plt.grid(linestyle='--',b=True, which='major')
plt.ylabel('Frecuencia absoluta')
plt.title('Histograma de división del conjunto de entrenamiento', fontsize=14)
plt.show()
print('jazz and blues: 0 \nsoul and reggae: 1')
# Out:
# jazz and blues: 0
# soul and reggae: 1

# %% [markdown]
# ## Red neural con una capa escondida

# %% [markdown]
# Inicialmente se evalua el perceptrón multicapa con una sola capa escondida. Entre los muchos parámetros que habría que definir para obtener una solución óptima, en este caso se definirá cual es el número de neuronas apropiado para obtener los mejores resultados de clasificación con el modelo seleccionado. Adicionalmente se evaluarán diferentes funciones de evaluación, tasas de aprendizaje y algoritmos para el entrenamiento de las redes. Este proceso de selección del número de neuras con la mejor función de activación, tasa de aprendizaje y algoritmo es presentado a continuación. Este mismo proceso será realizado para todas los perceptrones multinivel evaluados en este notebook.
#
# Cabe resaltar que en este estudio no se tuvo en cuenta el algoritmo ```lbfgs```, el cual es un optimizador de la familia de los métodos de quasi-Newton, puesto que en muchas ocasiones para los casos estudiados necesitaba por encima de las 5000 iteraciones, por lo que requería un trabajo computacional bastante amplio. De los casos análizados en este estudio, se pudo notar que no proveía mejor precisión que los métodos ```sdg``` y ```adam```.  El método ```lbfgs``` lo recomiendan usar cuando se usan conjuntos de datos pequeños, típicamente por debajo de la escala de miles, es decir, cientos de datos típicamente.
#
# Adicionalmente, se encuentra que un valor adecuado para el número máximo de iteraciones es 1200, puesto que con este valor se obtiene la convergencia de los algoritmos implementados.
#
# Es importante mencionar que se está seleccionando como máximo 200 neuronas y sólo se están evalando 5 valores, también por tratar de reducir el tiempo de cómputo.

# %%
activacion = ['identity', 'logistic', 'tanh', 'relu'] #todas las posibles funciones de activación
tasas_aprendizaje = ['constant', 'invscaling', 'adaptive'] #todas las posibles tasas de aprendizaje
algoritmo = ['lbfgs', 'sgd', 'adam'] #los posibles algoritmos
n = 250
step = 50
top_5 = []
u=0
for i in range(2, n, step):
  for j in activacion:
    for k in tasas_aprendizaje:
      for l in algoritmo:
        try:
          MLP = MLPClassifier(hidden_layer_sizes=(i,),activation=j, learning_rate=k, solver=l)      
          with warnings.catch_warnings():  
            warnings.filterwarnings("error", category=ConvergenceWarning,
                                    module="sklearn")
            clf = MLP.fit(x_train1, y_train1)
            score =clf.score(x_test1, y_test1)
            celda = [score, i, j, k, l]
            top_5.append(celda) 
            mensaje = 'La combinación ' + j + ' - ' + k + ' - ' + l + ' converge con ' + str(i) +' neuronas'
          print(mensaje)
        except:
          mensaje = 'La combinación ' + j + ' - ' + k + ' - ' + l + ' no converge con ' + str(i) + ' neuronas'
          print(mensaje)
# Out:
# La combinación identity - constant - lbfgs no converge con 2 neuronas
# La combinación identity - constant - sgd no converge con 2 neuronas
# La combinación identity - constant - adam no converge con 2 neuronas
# La combinación identity - invscaling - lbfgs converge con 2 neuronas
# La combinación identity - invscaling - sgd converge con 2 neuronas
# La combinación identity - invscaling - adam no converge con 2 neuronas
# La combinación identity - adaptive - lbfgs no converge con 2 neuronas
# La combinación identity - adaptive - sgd no converge con 2 neuronas
# La combinación identity - adaptive - adam no converge con 2 neuronas
# La combinación logistic - constant - lbfgs no converge con 2 neuronas
# La combinación logistic - constant - sgd converge con 2 neuronas
# La combinación logistic - constant - adam no converge con 2 neuronas
# La combinación logistic - invscaling - lbfgs no converge con 2 neuronas
# La combinación logistic - invscaling - sgd converge con 2 neuronas
# La combinación logistic - invscaling - adam no converge con 2 neuronas
# La combinación logistic - adaptive - lbfgs no converge con 2 neuronas
# La combinación logistic - adaptive - sgd converge con 2 neuronas
# La combinación logistic - adaptive - adam no converge con 2 neuronas
# La combinación tanh - constant - lbfgs no converge con 2 neuronas
# La combinación tanh - constant - sgd no converge con 2 neuronas
# La combinación tanh - constant - adam no converge con 2 neuronas
# La combinación tanh - invscaling - lbfgs no converge con 2 neuronas
# La combinación tanh - invscaling - sgd converge con 2 neuronas
# La combinación tanh - invscaling - adam no converge con 2 neuronas
# La combinación tanh - adaptive - lbfgs no converge con 2 neuronas
# La combinación tanh - adaptive - sgd no converge con 2 neuronas
# La combinación tanh - adaptive - adam no converge con 2 neuronas
# La combinación relu - constant - lbfgs converge con 2 neuronas
# La combinación relu - constant - sgd converge con 2 neuronas
# La combinación relu - constant - adam no converge con 2 neuronas
# La combinación relu - invscaling - lbfgs converge con 2 neuronas
# La combinación relu - invscaling - sgd converge con 2 neuronas
# La combinación relu - invscaling - adam converge con 2 neuronas
# La combinación relu - adaptive - lbfgs converge con 2 neuronas
# La combinación relu - adaptive - sgd no converge con 2 neuronas
# La combinación relu - adaptive - adam no converge con 2 neuronas
# La combinación identity - constant - lbfgs converge con 52 neuronas
# La combinación identity - constant - sgd no converge con 52 neuronas
# La combinación identity - constant - adam converge con 52 neuronas
# La combinación identity - invscaling - lbfgs converge con 52 neuronas
# La combinación identity - invscaling - sgd converge con 52 neuronas
# La combinación identity - invscaling - adam converge con 52 neuronas
# La combinación identity - adaptive - lbfgs converge con 52 neuronas
# La combinación identity - adaptive - sgd no converge con 52 neuronas
# La combinación identity - adaptive - adam converge con 52 neuronas
# La combinación logistic - constant - lbfgs no converge con 52 neuronas
# La combinación logistic - constant - sgd no converge con 52 neuronas
# La combinación logistic - constant - adam converge con 52 neuronas
# La combinación logistic - invscaling - lbfgs no converge con 52 neuronas
# La combinación logistic - invscaling - sgd converge con 52 neuronas
# La combinación logistic - invscaling - adam converge con 52 neuronas
# La combinación logistic - adaptive - lbfgs no converge con 52 neuronas
# La combinación logistic - adaptive - sgd no converge con 52 neuronas
# La combinación logistic - adaptive - adam converge con 52 neuronas
# La combinación tanh - constant - lbfgs no converge con 52 neuronas
# La combinación tanh - constant - sgd no converge con 52 neuronas
# La combinación tanh - constant - adam converge con 52 neuronas
# La combinación tanh - invscaling - lbfgs no converge con 52 neuronas
# La combinación tanh - invscaling - sgd converge con 52 neuronas
# La combinación tanh - invscaling - adam converge con 52 neuronas
# La combinación tanh - adaptive - lbfgs no converge con 52 neuronas
# La combinación tanh - adaptive - sgd no converge con 52 neuronas
# La combinación tanh - adaptive - adam converge con 52 neuronas
# La combinación relu - constant - lbfgs no converge con 52 neuronas
# La combinación relu - constant - sgd no converge con 52 neuronas
# La combinación relu - constant - adam no converge con 52 neuronas
# La combinación relu - invscaling - lbfgs no converge con 52 neuronas
# La combinación relu - invscaling - sgd converge con 52 neuronas
# La combinación relu - invscaling - adam no converge con 52 neuronas
# La combinación relu - adaptive - lbfgs no converge con 52 neuronas
# La combinación relu - adaptive - sgd no converge con 52 neuronas
# La combinación relu - adaptive - adam no converge con 52 neuronas
# La combinación identity - constant - lbfgs converge con 102 neuronas
# La combinación identity - constant - sgd no converge con 102 neuronas
# La combinación identity - constant - adam converge con 102 neuronas
# La combinación identity - invscaling - lbfgs converge con 102 neuronas
# La combinación identity - invscaling - sgd converge con 102 neuronas
# La combinación identity - invscaling - adam converge con 102 neuronas
# La combinación identity - adaptive - lbfgs converge con 102 neuronas
# La combinación identity - adaptive - sgd no converge con 102 neuronas
# La combinación identity - adaptive - adam converge con 102 neuronas
# La combinación logistic - constant - lbfgs no converge con 102 neuronas
# La combinación logistic - constant - sgd no converge con 102 neuronas
# La combinación logistic - constant - adam converge con 102 neuronas
# La combinación logistic - invscaling - lbfgs no converge con 102 neuronas
# La combinación logistic - invscaling - sgd converge con 102 neuronas
# La combinación logistic - invscaling - adam converge con 102 neuronas
# La combinación logistic - adaptive - lbfgs no converge con 102 neuronas
# La combinación logistic - adaptive - sgd no converge con 102 neuronas
# La combinación logistic - adaptive - adam converge con 102 neuronas
# La combinación tanh - constant - lbfgs no converge con 102 neuronas
# La combinación tanh - constant - sgd no converge con 102 neuronas
# La combinación tanh - constant - adam converge con 102 neuronas
# La combinación tanh - invscaling - lbfgs no converge con 102 neuronas
# La combinación tanh - invscaling - sgd converge con 102 neuronas
# La combinación tanh - invscaling - adam converge con 102 neuronas
# La combinación tanh - adaptive - lbfgs no converge con 102 neuronas
# La combinación tanh - adaptive - sgd no converge con 102 neuronas
# La combinación tanh - adaptive - adam converge con 102 neuronas
# La combinación relu - constant - lbfgs no converge con 102 neuronas
# La combinación relu - constant - sgd no converge con 102 neuronas
# La combinación relu - constant - adam no converge con 102 neuronas
# La combinación relu - invscaling - lbfgs no converge con 102 neuronas
# La combinación relu - invscaling - sgd converge con 102 neuronas
# La combinación relu - invscaling - adam no converge con 102 neuronas
# La combinación relu - adaptive - lbfgs no converge con 102 neuronas
# La combinación relu - adaptive - sgd no converge con 102 neuronas
# La combinación relu - adaptive - adam no converge con 102 neuronas
# La combinación identity - constant - lbfgs converge con 152 neuronas
# La combinación identity - constant - sgd no converge con 152 neuronas
# La combinación identity - constant - adam converge con 152 neuronas
# La combinación identity - invscaling - lbfgs converge con 152 neuronas
# La combinación identity - invscaling - sgd converge con 152 neuronas
# La combinación identity - invscaling - adam converge con 152 neuronas
# La combinación identity - adaptive - lbfgs converge con 152 neuronas
# La combinación identity - adaptive - sgd no converge con 152 neuronas
# La combinación identity - adaptive - adam converge con 152 neuronas
# La combinación logistic - constant - lbfgs no converge con 152 neuronas
# La combinación logistic - constant - sgd no converge con 152 neuronas
# La combinación logistic - constant - adam converge con 152 neuronas
# La combinación logistic - invscaling - lbfgs converge con 152 neuronas
# La combinación logistic - invscaling - sgd converge con 152 neuronas
# La combinación logistic - invscaling - adam converge con 152 neuronas
# La combinación logistic - adaptive - lbfgs no converge con 152 neuronas
# La combinación logistic - adaptive - sgd no converge con 152 neuronas
# La combinación logistic - adaptive - adam converge con 152 neuronas
# La combinación tanh - constant - lbfgs no converge con 152 neuronas
# La combinación tanh - constant - sgd no converge con 152 neuronas
# La combinación tanh - constant - adam converge con 152 neuronas
# La combinación tanh - invscaling - lbfgs no converge con 152 neuronas
# La combinación tanh - invscaling - sgd converge con 152 neuronas
# La combinación tanh - invscaling - adam converge con 152 neuronas
# La combinación tanh - adaptive - lbfgs no converge con 152 neuronas
# La combinación tanh - adaptive - sgd no converge con 152 neuronas
# La combinación tanh - adaptive - adam converge con 152 neuronas
# La combinación relu - constant - lbfgs no converge con 152 neuronas
# La combinación relu - constant - sgd no converge con 152 neuronas
# La combinación relu - constant - adam no converge con 152 neuronas
# La combinación relu - invscaling - lbfgs no converge con 152 neuronas
# La combinación relu - invscaling - sgd converge con 152 neuronas
# La combinación relu - invscaling - adam no converge con 152 neuronas
# La combinación relu - adaptive - lbfgs no converge con 152 neuronas
# La combinación relu - adaptive - sgd no converge con 152 neuronas
# La combinación relu - adaptive - adam no converge con 152 neuronas
# La combinación identity - constant - lbfgs converge con 202 neuronas
# La combinación identity - constant - sgd no converge con 202 neuronas
# La combinación identity - constant - adam converge con 202 neuronas
# La combinación identity - invscaling - lbfgs converge con 202 neuronas
# La combinación identity - invscaling - sgd converge con 202 neuronas
# La combinación identity - invscaling - adam converge con 202 neuronas
# La combinación identity - adaptive - lbfgs converge con 202 neuronas
# La combinación identity - adaptive - sgd no converge con 202 neuronas
# La combinación identity - adaptive - adam converge con 202 neuronas
# La combinación logistic - constant - lbfgs no converge con 202 neuronas
# La combinación logistic - constant - sgd no converge con 202 neuronas
# La combinación logistic - constant - adam converge con 202 neuronas
# La combinación logistic - invscaling - lbfgs no converge con 202 neuronas
# La combinación logistic - invscaling - sgd converge con 202 neuronas
# La combinación logistic - invscaling - adam converge con 202 neuronas
# La combinación logistic - adaptive - lbfgs no converge con 202 neuronas
# La combinación logistic - adaptive - sgd no converge con 202 neuronas
# La combinación logistic - adaptive - adam converge con 202 neuronas
# La combinación tanh - constant - lbfgs no converge con 202 neuronas
# La combinación tanh - constant - sgd no converge con 202 neuronas
# La combinación tanh - constant - adam converge con 202 neuronas
# La combinación tanh - invscaling - lbfgs no converge con 202 neuronas
# La combinación tanh - invscaling - sgd converge con 202 neuronas
# La combinación tanh - invscaling - adam converge con 202 neuronas
# La combinación tanh - adaptive - lbfgs no converge con 202 neuronas
# La combinación tanh - adaptive - sgd no converge con 202 neuronas
# La combinación tanh - adaptive - adam converge con 202 neuronas
# La combinación relu - constant - lbfgs no converge con 202 neuronas
# La combinación relu - constant - sgd no converge con 202 neuronas
# La combinación relu - constant - adam no converge con 202 neuronas
# La combinación relu - invscaling - lbfgs no converge con 202 neuronas
# La combinación relu - invscaling - sgd converge con 202 neuronas
# La combinación relu - invscaling - adam no converge con 202 neuronas
# La combinación relu - adaptive - lbfgs no converge con 202 neuronas
# La combinación relu - adaptive - sgd no converge con 202 neuronas
# La combinación relu - adaptive - adam no converge con 202 neuronas

# %% [markdown]
# A continuación se presenta la tabla con los resultados para el mejores score resultante en la validación de las redes en la capa escondida.

# %%
resul1 = pd.DataFrame(data=top_5, columns=['score','N', 'Función de Activación', 'Tasa de aprendizaje', 'Algoritmo'])
resul1 = resul1.sort_values(by=['score'], ascending=False)
resul1.head()
# Out:
#        score    N Función de Activación Tasa de aprendizaje Algoritmo
# 42  0.831587  102                  tanh            adaptive      adam
# 46  0.830090  152              identity          invscaling     lbfgs
# 72  0.830090  202                  tanh            constant      adam
# 62  0.830090  202              identity            constant      adam
# 13  0.830090   52              identity            constant      adam

# %% [markdown]
# Para una mejor visualización del comportamiento de cada uno de los parámetros estudiados, se presenta la siguiente gráfica que resume los resultados obtenidos para el caso en el que se usa el algoritmo "sgd" y el algoritmo "adam".

# %%
f = plt.figure(figsize=(18,6))
f.suptitle('Comparación de los parámetros seleccionados teniendo en cuenta los algoritmos en la primera capa escondida', y=1.2, fontsize=16)

plot_args = [{'c': 'blue', 'linestyle': '-'},
             {'c': 'orange', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'red', 'linestyle': '-'},
             {'c': 'olive', 'linestyle': '-'},
             {'c': 'magenta', 'linestyle': '-'},
             {'c': 'black', 'linestyle': '--'},
             {'c': 'yellowgreen', 'linestyle': '--'},
             {'c': 'violet', 'linestyle': '--'},
             {'c': 'tomato', 'linestyle': '--'},
             {'c': 'navy', 'linestyle': '--'},
             {'c': 'brown', 'linestyle': '--'}]

cont=1
args = 0
labels = []
for alg in algoritmo:
  ax = plt.subplot(2,2,cont)
  ax.set_title(r'$\bf{Algoritmo~}$'+r'$\bf{}$'.format(alg), fontsize=14)
  ax.set_ylabel('Score')
  ax.set_xlabel('Número de neuronas (N)')
  ax.grid(linestyle='--',b=True, which='major')
  for act in activacion:
    for rate in tasas_aprendizaje:
      temp = resul1.loc[(resul1['Función de Activación']==act) & (resul1['Tasa de aprendizaje']==rate) & (resul1['Algoritmo']==alg)]
      temp = temp.sort_values(by=['N'], ascending=True)
      ax.plot(temp['N'].values, temp['score'].values, **plot_args[args])
      labels.append(r'$\bf{act:}$ ' + act + ' + ' + r'$\bf{tasa:}$ ' + rate)
      if args < 11:
        args = args + 1
      else:
        args = 0

  f.legend(ax.get_lines(), labels, ncol=3, loc="lower center", bbox_to_anchor=(0.4, 0.9))
  cont = cont+1

# %% [markdown]
# Teniendo en cuenta la combinación de parámetros con el porcentaje de precisión más alto, se procede a correr el modelo de perceptrón multinivel para los datos de prueba, el modelo de entrenamiento del clasificador es presentado a continuación.

# %%
# Se presentan los parámetros apropiados
N = resul1.iloc[0,:]['N'] # El número de neuronas apropiado obtenido previamente
activation = resul1.iloc[0,:]['Función de Activación'] # La función de activación
learning_rate = resul1.iloc[0,:]['Tasa de aprendizaje'] # Tasa de aprendizaje
algor = resul1.iloc[0,:]['Algoritmo'] # Algoritmo seleccionado

MLP_1L = MLPClassifier(hidden_layer_sizes=(N,),activation=activation, learning_rate=learning_rate, solver=algor,max_iter=1200)
Hidden_1L = MLP_1L.fit(x_train, y_train)

# %% [markdown]
# La precisión del modelo seleccionado es evaluada en la siguiente entrada de código.

# %%
result_1L = Hidden_1L.score(x_test, y_test)
print('El modelo tiene una precisión del {:.2f}%'.format(result_1L*100))
# Out:
# El modelo tiene una precisión del 83.29%

# %% [markdown]
# Para complementar la validación del modelo, se presenta la matriz de confusión, donde se puede detallar el porcentaje normalizado de los aciertos y desaciertos del modelo para cada una de las variables a clasificar. En este caso la diagonal corresponde al porcentaje normalizado del acierto de la predicción, mientras que los elementos fuera de la diagonal representan el porcentaje de desacierto para cada variable.

# %%
class_names = ['jazz and blues','soul and reggae']
plot_confusion_matrix(Hidden_1L, x_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues, normalize = 'true')
plt.title('Matriz de confusiones normalizada', fontsize = 14)
plt.show()

# %% [markdown]
# ## Red neural con 2 capas escondidas
#
# En este caso, con el fin de reducir el proceso computacional, se asumirá que el conjunto de parámetros óptimo seleccionado para el caso de una sola capa escondida, corresponderán a los parámetros de la primera capa escondida de este caso en particular. Es posible que esto no sea el mejor modelo, sin embargo, implementarlo tomaría mucho tiempo y recurso computacional, con el fin de ahorrar este tiempo, se optó por tener en cuenta la presunción previamente mencionada.

# %%
n1 = 250
n2 = 152
step1 = 50
step2 = 30
top_5 = []
u=0
for i in range(2, n1, step1):
  for m in range(2, n2, step2):
    for j in activacion:
      for k in tasas_aprendizaje:
        for l in algoritmo:       
          try:
            MLP = MLPClassifier(hidden_layer_sizes=(i,m,),activation=j, learning_rate=k, solver=l,max_iter=200)      
            with warnings.catch_warnings():  
              warnings.filterwarnings("error", category=ConvergenceWarning,
                                      module="sklearn")
              clf = MLP.fit(x_train1, y_train1)
              score =clf.score(x_test1, y_test1)
              celda = [score, i, j, k, l]
              top_5.append(celda) 
              mensaje = 'La combinación ' + j + ' - ' + k + ' - ' + l + ' converge con ' + str(i) + ' - ' + str(m)
            print(mensaje)
          except:
            mensaje = 'La combinación ' + j + ' - ' + k + ' - ' + l + ' no converge con ' + str(i) + ' - ' + str(m)
            print(mensaje)
# Out:
# La combinación identity - constant - lbfgs converge con 2 - 2
# La combinación identity - constant - sgd no converge con 2 - 2
# La combinación identity - constant - adam converge con 2 - 2
# La combinación identity - invscaling - lbfgs converge con 2 - 2
# La combinación identity - invscaling - sgd converge con 2 - 2
# La combinación identity - invscaling - adam converge con 2 - 2
# La combinación identity - adaptive - lbfgs converge con 2 - 2
# La combinación identity - adaptive - sgd no converge con 2 - 2
# La combinación identity - adaptive - adam no converge con 2 - 2
# La combinación logistic - constant - lbfgs no converge con 2 - 2
# La combinación logistic - constant - sgd converge con 2 - 2
# La combinación logistic - constant - adam no converge con 2 - 2
# La combinación logistic - invscaling - lbfgs no converge con 2 - 2
# La combinación logistic - invscaling - sgd converge con 2 - 2
# La combinación logistic - invscaling - adam converge con 2 - 2
# La combinación logistic - adaptive - lbfgs no converge con 2 - 2
# La combinación logistic - adaptive - sgd converge con 2 - 2
# La combinación logistic - adaptive - adam no converge con 2 - 2
# La combinación tanh - constant - lbfgs no converge con 2 - 2
# La combinación tanh - constant - sgd no converge con 2 - 2
# La combinación tanh - constant - adam no converge con 2 - 2
# La combinación tanh - invscaling - lbfgs no converge con 2 - 2
# La combinación tanh - invscaling - sgd converge con 2 - 2
# La combinación tanh - invscaling - adam no converge con 2 - 2
# La combinación tanh - adaptive - lbfgs no converge con 2 - 2
# La combinación tanh - adaptive - sgd no converge con 2 - 2
# La combinación tanh - adaptive - adam converge con 2 - 2
# La combinación relu - constant - lbfgs no converge con 2 - 2
# La combinación relu - constant - sgd converge con 2 - 2
# La combinación relu - constant - adam no converge con 2 - 2
# La combinación relu - invscaling - lbfgs converge con 2 - 2
# La combinación relu - invscaling - sgd converge con 2 - 2
# La combinación relu - invscaling - adam no converge con 2 - 2
# La combinación relu - adaptive - lbfgs converge con 2 - 2
# La combinación relu - adaptive - sgd converge con 2 - 2
# La combinación relu - adaptive - adam converge con 2 - 2
# La combinación identity - constant - lbfgs converge con 2 - 32
# La combinación identity - constant - sgd no converge con 2 - 32
# La combinación identity - constant - adam converge con 2 - 32
# La combinación identity - invscaling - lbfgs no converge con 2 - 32
# La combinación identity - invscaling - sgd converge con 2 - 32
# La combinación identity - invscaling - adam converge con 2 - 32
# La combinación identity - adaptive - lbfgs converge con 2 - 32
# La combinación identity - adaptive - sgd no converge con 2 - 32
# La combinación identity - adaptive - adam converge con 2 - 32
# La combinación logistic - constant - lbfgs no converge con 2 - 32
# La combinación logistic - constant - sgd converge con 2 - 32
# La combinación logistic - constant - adam no converge con 2 - 32
# La combinación logistic - invscaling - lbfgs no converge con 2 - 32
# La combinación logistic - invscaling - sgd converge con 2 - 32
# La combinación logistic - invscaling - adam no converge con 2 - 32
# La combinación logistic - adaptive - lbfgs no converge con 2 - 32
# La combinación logistic - adaptive - sgd converge con 2 - 32
# La combinación logistic - adaptive - adam no converge con 2 - 32
# La combinación tanh - constant - lbfgs no converge con 2 - 32
# La combinación tanh - constant - sgd no converge con 2 - 32
# La combinación tanh - constant - adam converge con 2 - 32
# La combinación tanh - invscaling - lbfgs no converge con 2 - 32
# La combinación tanh - invscaling - sgd converge con 2 - 32
# La combinación tanh - invscaling - adam converge con 2 - 32
# La combinación tanh - adaptive - lbfgs no converge con 2 - 32
# La combinación tanh - adaptive - sgd no converge con 2 - 32
# La combinación tanh - adaptive - adam converge con 2 - 32
# La combinación relu - constant - lbfgs no converge con 2 - 32
# La combinación relu - constant - sgd no converge con 2 - 32
# La combinación relu - constant - adam converge con 2 - 32
# La combinación relu - invscaling - lbfgs no converge con 2 - 32
# La combinación relu - invscaling - sgd converge con 2 - 32
# La combinación relu - invscaling - adam no converge con 2 - 32
# La combinación relu - adaptive - lbfgs converge con 2 - 32
# La combinación relu - adaptive - sgd converge con 2 - 32
# La combinación relu - adaptive - adam converge con 2 - 32
# La combinación identity - constant - lbfgs no converge con 2 - 62
# La combinación identity - constant - sgd no converge con 2 - 62
# La combinación identity - constant - adam converge con 2 - 62
# La combinación identity - invscaling - lbfgs no converge con 2 - 62
# La combinación identity - invscaling - sgd converge con 2 - 62
# La combinación identity - invscaling - adam converge con 2 - 62
# La combinación identity - adaptive - lbfgs converge con 2 - 62
# La combinación identity - adaptive - sgd no converge con 2 - 62
# La combinación identity - adaptive - adam converge con 2 - 62
# La combinación logistic - constant - lbfgs no converge con 2 - 62
# La combinación logistic - constant - sgd converge con 2 - 62
# La combinación logistic - constant - adam no converge con 2 - 62
# La combinación logistic - invscaling - lbfgs no converge con 2 - 62
# La combinación logistic - invscaling - sgd converge con 2 - 62
# La combinación logistic - invscaling - adam no converge con 2 - 62
# La combinación logistic - adaptive - lbfgs no converge con 2 - 62
# La combinación logistic - adaptive - sgd converge con 2 - 62
# La combinación logistic - adaptive - adam no converge con 2 - 62
# La combinación tanh - constant - lbfgs no converge con 2 - 62
# La combinación tanh - constant - sgd no converge con 2 - 62
# La combinación tanh - constant - adam converge con 2 - 62
# La combinación tanh - invscaling - lbfgs no converge con 2 - 62
# La combinación tanh - invscaling - sgd converge con 2 - 62
# La combinación tanh - invscaling - adam converge con 2 - 62
# La combinación tanh - adaptive - lbfgs no converge con 2 - 62
# La combinación tanh - adaptive - sgd no converge con 2 - 62
# La combinación tanh - adaptive - adam converge con 2 - 62
# La combinación relu - constant - lbfgs converge con 2 - 62
# La combinación relu - constant - sgd converge con 2 - 62
# La combinación relu - constant - adam converge con 2 - 62
# La combinación relu - invscaling - lbfgs no converge con 2 - 62
# La combinación relu - invscaling - sgd converge con 2 - 62
# La combinación relu - invscaling - adam converge con 2 - 62
# La combinación relu - adaptive - lbfgs no converge con 2 - 62
# La combinación relu - adaptive - sgd no converge con 2 - 62
# La combinación relu - adaptive - adam converge con 2 - 62
# La combinación identity - constant - lbfgs converge con 2 - 92
# La combinación identity - constant - sgd no converge con 2 - 92
# La combinación identity - constant - adam converge con 2 - 92
# La combinación identity - invscaling - lbfgs converge con 2 - 92
# La combinación identity - invscaling - sgd converge con 2 - 92
# La combinación identity - invscaling - adam no converge con 2 - 92
# La combinación identity - adaptive - lbfgs converge con 2 - 92
# La combinación identity - adaptive - sgd no converge con 2 - 92
# La combinación identity - adaptive - adam converge con 2 - 92
# La combinación logistic - constant - lbfgs no converge con 2 - 92
# La combinación logistic - constant - sgd converge con 2 - 92
# La combinación logistic - constant - adam no converge con 2 - 92
# La combinación logistic - invscaling - lbfgs no converge con 2 - 92
# La combinación logistic - invscaling - sgd converge con 2 - 92
# La combinación logistic - invscaling - adam no converge con 2 - 92
# La combinación logistic - adaptive - lbfgs no converge con 2 - 92
# La combinación logistic - adaptive - sgd converge con 2 - 92
# La combinación logistic - adaptive - adam converge con 2 - 92
# La combinación tanh - constant - lbfgs no converge con 2 - 92
# La combinación tanh - constant - sgd no converge con 2 - 92
# La combinación tanh - constant - adam converge con 2 - 92
# La combinación tanh - invscaling - lbfgs no converge con 2 - 92
# La combinación tanh - invscaling - sgd converge con 2 - 92
# La combinación tanh - invscaling - adam converge con 2 - 92
# La combinación tanh - adaptive - lbfgs no converge con 2 - 92
# La combinación tanh - adaptive - sgd converge con 2 - 92
# La combinación tanh - adaptive - adam converge con 2 - 92
# La combinación relu - constant - lbfgs no converge con 2 - 92
# La combinación relu - constant - sgd no converge con 2 - 92
# La combinación relu - constant - adam converge con 2 - 92
# La combinación relu - invscaling - lbfgs converge con 2 - 92
# La combinación relu - invscaling - sgd converge con 2 - 92
# La combinación relu - invscaling - adam converge con 2 - 92
# La combinación relu - adaptive - lbfgs converge con 2 - 92
# La combinación relu - adaptive - sgd converge con 2 - 92
# La combinación relu - adaptive - adam converge con 2 - 92
# La combinación identity - constant - lbfgs no converge con 2 - 122
# La combinación identity - constant - sgd converge con 2 - 122
# La combinación identity - constant - adam converge con 2 - 122
# La combinación identity - invscaling - lbfgs no converge con 2 - 122
# La combinación identity - invscaling - sgd converge con 2 - 122
# La combinación identity - invscaling - adam converge con 2 - 122
# La combinación identity - adaptive - lbfgs no converge con 2 - 122
# La combinación identity - adaptive - sgd no converge con 2 - 122
# La combinación identity - adaptive - adam converge con 2 - 122
# La combinación logistic - constant - lbfgs converge con 2 - 122
# La combinación logistic - constant - sgd converge con 2 - 122
# La combinación logistic - constant - adam converge con 2 - 122
# La combinación logistic - invscaling - lbfgs no converge con 2 - 122
# La combinación logistic - invscaling - sgd converge con 2 - 122
# La combinación logistic - invscaling - adam converge con 2 - 122
# La combinación logistic - adaptive - lbfgs no converge con 2 - 122
# La combinación logistic - adaptive - sgd converge con 2 - 122
# La combinación logistic - adaptive - adam no converge con 2 - 122
# La combinación tanh - constant - lbfgs no converge con 2 - 122
# La combinación tanh - constant - sgd no converge con 2 - 122
# La combinación tanh - constant - adam no converge con 2 - 122
# La combinación tanh - invscaling - lbfgs no converge con 2 - 122
# La combinación tanh - invscaling - sgd converge con 2 - 122
# La combinación tanh - invscaling - adam converge con 2 - 122
# La combinación tanh - adaptive - lbfgs no converge con 2 - 122
# La combinación tanh - adaptive - sgd converge con 2 - 122
# La combinación tanh - adaptive - adam no converge con 2 - 122
# La combinación relu - constant - lbfgs no converge con 2 - 122
# La combinación relu - constant - sgd no converge con 2 - 122
# La combinación relu - constant - adam converge con 2 - 122
# La combinación relu - invscaling - lbfgs converge con 2 - 122
# La combinación relu - invscaling - sgd converge con 2 - 122
# La combinación relu - invscaling - adam converge con 2 - 122
# La combinación relu - adaptive - lbfgs no converge con 2 - 122
# La combinación relu - adaptive - sgd no converge con 2 - 122
# La combinación relu - adaptive - adam converge con 2 - 122
# La combinación identity - constant - lbfgs converge con 52 - 2
# La combinación identity - constant - sgd no converge con 52 - 2
# La combinación identity - constant - adam converge con 52 - 2
# La combinación identity - invscaling - lbfgs converge con 52 - 2
# La combinación identity - invscaling - sgd converge con 52 - 2
# La combinación identity - invscaling - adam converge con 52 - 2
# La combinación identity - adaptive - lbfgs converge con 52 - 2
# La combinación identity - adaptive - sgd no converge con 52 - 2
# La combinación identity - adaptive - adam converge con 52 - 2
# La combinación logistic - constant - lbfgs converge con 52 - 2
# La combinación logistic - constant - sgd converge con 52 - 2
# La combinación logistic - constant - adam no converge con 52 - 2
# La combinación logistic - invscaling - lbfgs no converge con 52 - 2
# La combinación logistic - invscaling - sgd converge con 52 - 2
# La combinación logistic - invscaling - adam no converge con 52 - 2
# La combinación logistic - adaptive - lbfgs no converge con 52 - 2
# La combinación logistic - adaptive - sgd converge con 52 - 2
# La combinación logistic - adaptive - adam no converge con 52 - 2
# La combinación tanh - constant - lbfgs no converge con 52 - 2
# La combinación tanh - constant - sgd converge con 52 - 2
# La combinación tanh - constant - adam converge con 52 - 2
# La combinación tanh - invscaling - lbfgs no converge con 52 - 2
# La combinación tanh - invscaling - sgd converge con 52 - 2
# La combinación tanh - invscaling - adam no converge con 52 - 2
# La combinación tanh - adaptive - lbfgs no converge con 52 - 2
# La combinación tanh - adaptive - sgd no converge con 52 - 2
# La combinación tanh - adaptive - adam no converge con 52 - 2
# La combinación relu - constant - lbfgs converge con 52 - 2
# La combinación relu - constant - sgd converge con 52 - 2
# La combinación relu - constant - adam no converge con 52 - 2
# La combinación relu - invscaling - lbfgs no converge con 52 - 2
# La combinación relu - invscaling - sgd converge con 52 - 2
# La combinación relu - invscaling - adam no converge con 52 - 2
# La combinación relu - adaptive - lbfgs converge con 52 - 2
# La combinación relu - adaptive - sgd no converge con 52 - 2
# La combinación relu - adaptive - adam no converge con 52 - 2
# La combinación identity - constant - lbfgs converge con 52 - 32
# La combinación identity - constant - sgd no converge con 52 - 32
# La combinación identity - constant - adam converge con 52 - 32
# La combinación identity - invscaling - lbfgs converge con 52 - 32
# La combinación identity - invscaling - sgd converge con 52 - 32
# La combinación identity - invscaling - adam converge con 52 - 32
# La combinación identity - adaptive - lbfgs converge con 52 - 32
# La combinación identity - adaptive - sgd no converge con 52 - 32
# La combinación identity - adaptive - adam converge con 52 - 32
# La combinación logistic - constant - lbfgs no converge con 52 - 32
# La combinación logistic - constant - sgd converge con 52 - 32
# La combinación logistic - constant - adam converge con 52 - 32
# La combinación logistic - invscaling - lbfgs no converge con 52 - 32
# La combinación logistic - invscaling - sgd converge con 52 - 32
# La combinación logistic - invscaling - adam converge con 52 - 32
# La combinación logistic - adaptive - lbfgs no converge con 52 - 32
# La combinación logistic - adaptive - sgd converge con 52 - 32
# La combinación logistic - adaptive - adam converge con 52 - 32
# La combinación tanh - constant - lbfgs no converge con 52 - 32
# La combinación tanh - constant - sgd no converge con 52 - 32
# La combinación tanh - constant - adam converge con 52 - 32
# La combinación tanh - invscaling - lbfgs no converge con 52 - 32
# La combinación tanh - invscaling - sgd converge con 52 - 32
# La combinación tanh - invscaling - adam no converge con 52 - 32
# La combinación tanh - adaptive - lbfgs no converge con 52 - 32
# La combinación tanh - adaptive - sgd no converge con 52 - 32
# La combinación tanh - adaptive - adam no converge con 52 - 32
# La combinación relu - constant - lbfgs no converge con 52 - 32
# La combinación relu - constant - sgd no converge con 52 - 32
# La combinación relu - constant - adam no converge con 52 - 32
# La combinación relu - invscaling - lbfgs no converge con 52 - 32
# La combinación relu - invscaling - sgd converge con 52 - 32
# La combinación relu - invscaling - adam no converge con 52 - 32
# La combinación relu - adaptive - lbfgs no converge con 52 - 32
# La combinación relu - adaptive - sgd no converge con 52 - 32
# La combinación relu - adaptive - adam no converge con 52 - 32
# La combinación identity - constant - lbfgs converge con 52 - 62
# La combinación identity - constant - sgd no converge con 52 - 62
# La combinación identity - constant - adam converge con 52 - 62
# La combinación identity - invscaling - lbfgs converge con 52 - 62
# La combinación identity - invscaling - sgd converge con 52 - 62
# La combinación identity - invscaling - adam converge con 52 - 62
# La combinación identity - adaptive - lbfgs converge con 52 - 62
# La combinación identity - adaptive - sgd no converge con 52 - 62
# La combinación identity - adaptive - adam converge con 52 - 62
# La combinación logistic - constant - lbfgs no converge con 52 - 62
# La combinación logistic - constant - sgd converge con 52 - 62
# La combinación logistic - constant - adam converge con 52 - 62
# La combinación logistic - invscaling - lbfgs converge con 52 - 62
# La combinación logistic - invscaling - sgd converge con 52 - 62
# La combinación logistic - invscaling - adam converge con 52 - 62
# La combinación logistic - adaptive - lbfgs no converge con 52 - 62
# La combinación logistic - adaptive - sgd converge con 52 - 62
# La combinación logistic - adaptive - adam converge con 52 - 62
# La combinación tanh - constant - lbfgs no converge con 52 - 62
# La combinación tanh - constant - sgd no converge con 52 - 62
# La combinación tanh - constant - adam converge con 52 - 62
# La combinación tanh - invscaling - lbfgs no converge con 52 - 62
# La combinación tanh - invscaling - sgd converge con 52 - 62
# La combinación tanh - invscaling - adam converge con 52 - 62
# La combinación tanh - adaptive - lbfgs no converge con 52 - 62
# La combinación tanh - adaptive - sgd no converge con 52 - 62
# La combinación tanh - adaptive - adam converge con 52 - 62
# La combinación relu - constant - lbfgs no converge con 52 - 62
# La combinación relu - constant - sgd no converge con 52 - 62
# La combinación relu - constant - adam no converge con 52 - 62
# La combinación relu - invscaling - lbfgs no converge con 52 - 62
# La combinación relu - invscaling - sgd converge con 52 - 62
# La combinación relu - invscaling - adam no converge con 52 - 62
# La combinación relu - adaptive - lbfgs no converge con 52 - 62
# La combinación relu - adaptive - sgd no converge con 52 - 62
# La combinación relu - adaptive - adam no converge con 52 - 62
# La combinación identity - constant - lbfgs converge con 52 - 92
# La combinación identity - constant - sgd no converge con 52 - 92
# La combinación identity - constant - adam converge con 52 - 92
# La combinación identity - invscaling - lbfgs converge con 52 - 92
# La combinación identity - invscaling - sgd converge con 52 - 92
# La combinación identity - invscaling - adam converge con 52 - 92
# La combinación identity - adaptive - lbfgs converge con 52 - 92
# La combinación identity - adaptive - sgd no converge con 52 - 92
# La combinación identity - adaptive - adam converge con 52 - 92
# La combinación logistic - constant - lbfgs no converge con 52 - 92
# La combinación logistic - constant - sgd converge con 52 - 92
# La combinación logistic - constant - adam converge con 52 - 92
# La combinación logistic - invscaling - lbfgs no converge con 52 - 92
# La combinación logistic - invscaling - sgd converge con 52 - 92
# La combinación logistic - invscaling - adam converge con 52 - 92
# La combinación logistic - adaptive - lbfgs no converge con 52 - 92
# La combinación logistic - adaptive - sgd converge con 52 - 92
# La combinación logistic - adaptive - adam converge con 52 - 92
# La combinación tanh - constant - lbfgs no converge con 52 - 92
# La combinación tanh - constant - sgd no converge con 52 - 92
# La combinación tanh - constant - adam converge con 52 - 92
# La combinación tanh - invscaling - lbfgs no converge con 52 - 92
# La combinación tanh - invscaling - sgd converge con 52 - 92
# La combinación tanh - invscaling - adam converge con 52 - 92
# La combinación tanh - adaptive - lbfgs no converge con 52 - 92
# La combinación tanh - adaptive - sgd no converge con 52 - 92
# La combinación tanh - adaptive - adam converge con 52 - 92
# La combinación relu - constant - lbfgs no converge con 52 - 92
# La combinación relu - constant - sgd no converge con 52 - 92
# La combinación relu - constant - adam converge con 52 - 92
# La combinación relu - invscaling - lbfgs no converge con 52 - 92
# La combinación relu - invscaling - sgd converge con 52 - 92
# La combinación relu - invscaling - adam no converge con 52 - 92
# La combinación relu - adaptive - lbfgs no converge con 52 - 92
# La combinación relu - adaptive - sgd no converge con 52 - 92
# La combinación relu - adaptive - adam no converge con 52 - 92
# La combinación identity - constant - lbfgs converge con 52 - 122
# La combinación identity - constant - sgd no converge con 52 - 122
# La combinación identity - constant - adam converge con 52 - 122
# La combinación identity - invscaling - lbfgs converge con 52 - 122
# La combinación identity - invscaling - sgd converge con 52 - 122
# La combinación identity - invscaling - adam converge con 52 - 122
# La combinación identity - adaptive - lbfgs converge con 52 - 122
# La combinación identity - adaptive - sgd no converge con 52 - 122
# La combinación identity - adaptive - adam converge con 52 - 122
# La combinación logistic - constant - lbfgs converge con 52 - 122
# La combinación logistic - constant - sgd converge con 52 - 122
# La combinación logistic - constant - adam converge con 52 - 122
# La combinación logistic - invscaling - lbfgs no converge con 52 - 122
# La combinación logistic - invscaling - sgd converge con 52 - 122
# La combinación logistic - invscaling - adam converge con 52 - 122
# La combinación logistic - adaptive - lbfgs converge con 52 - 122
# La combinación logistic - adaptive - sgd converge con 52 - 122
# La combinación logistic - adaptive - adam converge con 52 - 122
# La combinación tanh - constant - lbfgs no converge con 52 - 122
# La combinación tanh - constant - sgd no converge con 52 - 122
# La combinación tanh - constant - adam converge con 52 - 122
# La combinación tanh - invscaling - lbfgs no converge con 52 - 122
# La combinación tanh - invscaling - sgd converge con 52 - 122
# La combinación tanh - invscaling - adam converge con 52 - 122
# La combinación tanh - adaptive - lbfgs no converge con 52 - 122
# La combinación tanh - adaptive - sgd no converge con 52 - 122
# La combinación tanh - adaptive - adam converge con 52 - 122
# La combinación relu - constant - lbfgs no converge con 52 - 122
# La combinación relu - constant - sgd no converge con 52 - 122
# La combinación relu - constant - adam no converge con 52 - 122
# La combinación relu - invscaling - lbfgs no converge con 52 - 122
# La combinación relu - invscaling - sgd converge con 52 - 122
# La combinación relu - invscaling - adam no converge con 52 - 122
# La combinación relu - adaptive - lbfgs no converge con 52 - 122
# La combinación relu - adaptive - sgd no converge con 52 - 122
# La combinación relu - adaptive - adam converge con 52 - 122
# La combinación identity - constant - lbfgs converge con 102 - 2
# La combinación identity - constant - sgd no converge con 102 - 2
# La combinación identity - constant - adam converge con 102 - 2
# La combinación identity - invscaling - lbfgs converge con 102 - 2
# La combinación identity - invscaling - sgd converge con 102 - 2
# La combinación identity - invscaling - adam converge con 102 - 2
# La combinación identity - adaptive - lbfgs converge con 102 - 2
# La combinación identity - adaptive - sgd no converge con 102 - 2
# La combinación identity - adaptive - adam converge con 102 - 2
# La combinación logistic - constant - lbfgs no converge con 102 - 2
# La combinación logistic - constant - sgd converge con 102 - 2
# La combinación logistic - constant - adam no converge con 102 - 2
# La combinación logistic - invscaling - lbfgs no converge con 102 - 2
# La combinación logistic - invscaling - sgd converge con 102 - 2
# La combinación logistic - invscaling - adam no converge con 102 - 2
# La combinación logistic - adaptive - lbfgs converge con 102 - 2
# La combinación logistic - adaptive - sgd converge con 102 - 2
# La combinación logistic - adaptive - adam no converge con 102 - 2
# La combinación tanh - constant - lbfgs no converge con 102 - 2
# La combinación tanh - constant - sgd no converge con 102 - 2
# La combinación tanh - constant - adam converge con 102 - 2
# La combinación tanh - invscaling - lbfgs no converge con 102 - 2
# La combinación tanh - invscaling - sgd converge con 102 - 2
# La combinación tanh - invscaling - adam converge con 102 - 2
# La combinación tanh - adaptive - lbfgs no converge con 102 - 2
# La combinación tanh - adaptive - sgd no converge con 102 - 2
# La combinación tanh - adaptive - adam converge con 102 - 2
# La combinación relu - constant - lbfgs converge con 102 - 2
# La combinación relu - constant - sgd no converge con 102 - 2
# La combinación relu - constant - adam no converge con 102 - 2
# La combinación relu - invscaling - lbfgs no converge con 102 - 2
# La combinación relu - invscaling - sgd converge con 102 - 2
# La combinación relu - invscaling - adam no converge con 102 - 2
# La combinación relu - adaptive - lbfgs no converge con 102 - 2
# La combinación relu - adaptive - sgd no converge con 102 - 2
# La combinación relu - adaptive - adam no converge con 102 - 2
# La combinación identity - constant - lbfgs converge con 102 - 32
# La combinación identity - constant - sgd no converge con 102 - 32
# La combinación identity - constant - adam converge con 102 - 32
# La combinación identity - invscaling - lbfgs converge con 102 - 32
# La combinación identity - invscaling - sgd converge con 102 - 32
# La combinación identity - invscaling - adam converge con 102 - 32
# La combinación identity - adaptive - lbfgs converge con 102 - 32
# La combinación identity - adaptive - sgd no converge con 102 - 32
# La combinación identity - adaptive - adam converge con 102 - 32
# La combinación logistic - constant - lbfgs no converge con 102 - 32
# La combinación logistic - constant - sgd converge con 102 - 32
# La combinación logistic - constant - adam converge con 102 - 32
# La combinación logistic - invscaling - lbfgs no converge con 102 - 32
# La combinación logistic - invscaling - sgd converge con 102 - 32
# La combinación logistic - invscaling - adam converge con 102 - 32
# La combinación logistic - adaptive - lbfgs no converge con 102 - 32
# La combinación logistic - adaptive - sgd converge con 102 - 32
# La combinación logistic - adaptive - adam converge con 102 - 32
# La combinación tanh - constant - lbfgs no converge con 102 - 32
# La combinación tanh - constant - sgd no converge con 102 - 32
# La combinación tanh - constant - adam no converge con 102 - 32
# La combinación tanh - invscaling - lbfgs no converge con 102 - 32
# La combinación tanh - invscaling - sgd converge con 102 - 32
# La combinación tanh - invscaling - adam no converge con 102 - 32
# La combinación tanh - adaptive - lbfgs no converge con 102 - 32
# La combinación tanh - adaptive - sgd no converge con 102 - 32
# La combinación tanh - adaptive - adam no converge con 102 - 32
# La combinación relu - constant - lbfgs no converge con 102 - 32
# La combinación relu - constant - sgd no converge con 102 - 32
# La combinación relu - constant - adam no converge con 102 - 32
# La combinación relu - invscaling - lbfgs no converge con 102 - 32
# La combinación relu - invscaling - sgd converge con 102 - 32
# La combinación relu - invscaling - adam no converge con 102 - 32
# La combinación relu - adaptive - lbfgs converge con 102 - 32
# La combinación relu - adaptive - sgd no converge con 102 - 32
# La combinación relu - adaptive - adam no converge con 102 - 32
# La combinación identity - constant - lbfgs converge con 102 - 62
# La combinación identity - constant - sgd no converge con 102 - 62
# La combinación identity - constant - adam converge con 102 - 62
# La combinación identity - invscaling - lbfgs converge con 102 - 62
# La combinación identity - invscaling - sgd converge con 102 - 62
# La combinación identity - invscaling - adam converge con 102 - 62
# La combinación identity - adaptive - lbfgs converge con 102 - 62
# La combinación identity - adaptive - sgd no converge con 102 - 62
# La combinación identity - adaptive - adam converge con 102 - 62
# La combinación logistic - constant - lbfgs converge con 102 - 62
# La combinación logistic - constant - sgd converge con 102 - 62
# La combinación logistic - constant - adam converge con 102 - 62
# La combinación logistic - invscaling - lbfgs no converge con 102 - 62
# La combinación logistic - invscaling - sgd converge con 102 - 62
# La combinación logistic - invscaling - adam converge con 102 - 62
# La combinación logistic - adaptive - lbfgs converge con 102 - 62
# La combinación logistic - adaptive - sgd converge con 102 - 62
# La combinación logistic - adaptive - adam converge con 102 - 62
# La combinación tanh - constant - lbfgs no converge con 102 - 62
# La combinación tanh - constant - sgd no converge con 102 - 62
# La combinación tanh - constant - adam no converge con 102 - 62
# La combinación tanh - invscaling - lbfgs no converge con 102 - 62
# La combinación tanh - invscaling - sgd converge con 102 - 62
# La combinación tanh - invscaling - adam converge con 102 - 62
# La combinación tanh - adaptive - lbfgs no converge con 102 - 62
# La combinación tanh - adaptive - sgd no converge con 102 - 62
# La combinación tanh - adaptive - adam no converge con 102 - 62
# La combinación relu - constant - lbfgs no converge con 102 - 62
# La combinación relu - constant - sgd no converge con 102 - 62
# La combinación relu - constant - adam converge con 102 - 62
# La combinación relu - invscaling - lbfgs no converge con 102 - 62
# La combinación relu - invscaling - sgd converge con 102 - 62
# La combinación relu - invscaling - adam no converge con 102 - 62
# La combinación relu - adaptive - lbfgs no converge con 102 - 62
# La combinación relu - adaptive - sgd no converge con 102 - 62
# La combinación relu - adaptive - adam no converge con 102 - 62
# La combinación identity - constant - lbfgs converge con 102 - 92
# La combinación identity - constant - sgd no converge con 102 - 92
# La combinación identity - constant - adam converge con 102 - 92
# La combinación identity - invscaling - lbfgs converge con 102 - 92
# La combinación identity - invscaling - sgd converge con 102 - 92
# La combinación identity - invscaling - adam converge con 102 - 92
# La combinación identity - adaptive - lbfgs converge con 102 - 92
# La combinación identity - adaptive - sgd no converge con 102 - 92
# La combinación identity - adaptive - adam converge con 102 - 92
# La combinación logistic - constant - lbfgs no converge con 102 - 92
# La combinación logistic - constant - sgd converge con 102 - 92
# La combinación logistic - constant - adam converge con 102 - 92
# La combinación logistic - invscaling - lbfgs no converge con 102 - 92
# La combinación logistic - invscaling - sgd converge con 102 - 92
# La combinación logistic - invscaling - adam converge con 102 - 92
# La combinación logistic - adaptive - lbfgs no converge con 102 - 92
# La combinación logistic - adaptive - sgd converge con 102 - 92
# La combinación logistic - adaptive - adam converge con 102 - 92
# La combinación tanh - constant - lbfgs no converge con 102 - 92
# La combinación tanh - constant - sgd no converge con 102 - 92
# La combinación tanh - constant - adam converge con 102 - 92
# La combinación tanh - invscaling - lbfgs no converge con 102 - 92
# La combinación tanh - invscaling - sgd converge con 102 - 92
# La combinación tanh - invscaling - adam converge con 102 - 92
# La combinación tanh - adaptive - lbfgs no converge con 102 - 92
# La combinación tanh - adaptive - sgd no converge con 102 - 92
# La combinación tanh - adaptive - adam converge con 102 - 92
# La combinación relu - constant - lbfgs no converge con 102 - 92
# La combinación relu - constant - sgd no converge con 102 - 92
# La combinación relu - constant - adam converge con 102 - 92
# La combinación relu - invscaling - lbfgs no converge con 102 - 92
# La combinación relu - invscaling - sgd converge con 102 - 92
# La combinación relu - invscaling - adam no converge con 102 - 92
# La combinación relu - adaptive - lbfgs no converge con 102 - 92
# La combinación relu - adaptive - sgd no converge con 102 - 92
# La combinación relu - adaptive - adam no converge con 102 - 92
# La combinación identity - constant - lbfgs converge con 102 - 122
# La combinación identity - constant - sgd no converge con 102 - 122
# La combinación identity - constant - adam converge con 102 - 122
# La combinación identity - invscaling - lbfgs converge con 102 - 122
# La combinación identity - invscaling - sgd converge con 102 - 122
# La combinación identity - invscaling - adam converge con 102 - 122
# La combinación identity - adaptive - lbfgs converge con 102 - 122
# La combinación identity - adaptive - sgd no converge con 102 - 122
# La combinación identity - adaptive - adam converge con 102 - 122
# La combinación logistic - constant - lbfgs no converge con 102 - 122
# La combinación logistic - constant - sgd converge con 102 - 122
# La combinación logistic - constant - adam converge con 102 - 122
# La combinación logistic - invscaling - lbfgs no converge con 102 - 122
# La combinación logistic - invscaling - sgd converge con 102 - 122
# La combinación logistic - invscaling - adam converge con 102 - 122
# La combinación logistic - adaptive - lbfgs no converge con 102 - 122
# La combinación logistic - adaptive - sgd converge con 102 - 122
# La combinación logistic - adaptive - adam converge con 102 - 122
# La combinación tanh - constant - lbfgs no converge con 102 - 122
# La combinación tanh - constant - sgd no converge con 102 - 122
# La combinación tanh - constant - adam converge con 102 - 122
# La combinación tanh - invscaling - lbfgs no converge con 102 - 122
# La combinación tanh - invscaling - sgd converge con 102 - 122
# La combinación tanh - invscaling - adam no converge con 102 - 122
# La combinación tanh - adaptive - lbfgs no converge con 102 - 122
# La combinación tanh - adaptive - sgd no converge con 102 - 122
# La combinación tanh - adaptive - adam converge con 102 - 122
# La combinación relu - constant - lbfgs no converge con 102 - 122
# La combinación relu - constant - sgd no converge con 102 - 122
# La combinación relu - constant - adam no converge con 102 - 122
# La combinación relu - invscaling - lbfgs no converge con 102 - 122
# La combinación relu - invscaling - sgd converge con 102 - 122
# La combinación relu - invscaling - adam converge con 102 - 122
# La combinación relu - adaptive - lbfgs no converge con 102 - 122
# La combinación relu - adaptive - sgd no converge con 102 - 122
# La combinación relu - adaptive - adam no converge con 102 - 122
# La combinación identity - constant - lbfgs converge con 152 - 2
# La combinación identity - constant - sgd no converge con 152 - 2
# La combinación identity - constant - adam converge con 152 - 2
# La combinación identity - invscaling - lbfgs converge con 152 - 2
# La combinación identity - invscaling - sgd converge con 152 - 2
# La combinación identity - invscaling - adam converge con 152 - 2
# La combinación identity - adaptive - lbfgs converge con 152 - 2
# La combinación identity - adaptive - sgd no converge con 152 - 2
# La combinación identity - adaptive - adam converge con 152 - 2
# La combinación logistic - constant - lbfgs no converge con 152 - 2
# La combinación logistic - constant - sgd converge con 152 - 2
# La combinación logistic - constant - adam converge con 152 - 2
# La combinación logistic - invscaling - lbfgs converge con 152 - 2
# La combinación logistic - invscaling - sgd converge con 152 - 2
# La combinación logistic - invscaling - adam no converge con 152 - 2
# La combinación logistic - adaptive - lbfgs no converge con 152 - 2
# La combinación logistic - adaptive - sgd converge con 152 - 2
# La combinación logistic - adaptive - adam converge con 152 - 2
# La combinación tanh - constant - lbfgs no converge con 152 - 2
# La combinación tanh - constant - sgd no converge con 152 - 2
# La combinación tanh - constant - adam no converge con 152 - 2
# La combinación tanh - invscaling - lbfgs no converge con 152 - 2
# La combinación tanh - invscaling - sgd converge con 152 - 2
# La combinación tanh - invscaling - adam converge con 152 - 2
# La combinación tanh - adaptive - lbfgs no converge con 152 - 2
# La combinación tanh - adaptive - sgd no converge con 152 - 2
# La combinación tanh - adaptive - adam converge con 152 - 2
# La combinación relu - constant - lbfgs no converge con 152 - 2
# La combinación relu - constant - sgd no converge con 152 - 2
# La combinación relu - constant - adam no converge con 152 - 2
# La combinación relu - invscaling - lbfgs no converge con 152 - 2
# La combinación relu - invscaling - sgd converge con 152 - 2
# La combinación relu - invscaling - adam no converge con 152 - 2
# La combinación relu - adaptive - lbfgs converge con 152 - 2
# La combinación relu - adaptive - sgd no converge con 152 - 2
# La combinación relu - adaptive - adam converge con 152 - 2
# La combinación identity - constant - lbfgs converge con 152 - 32
# La combinación identity - constant - sgd no converge con 152 - 32
# La combinación identity - constant - adam converge con 152 - 32
# La combinación identity - invscaling - lbfgs converge con 152 - 32
# La combinación identity - invscaling - sgd converge con 152 - 32
# La combinación identity - invscaling - adam converge con 152 - 32
# La combinación identity - adaptive - lbfgs converge con 152 - 32
# La combinación identity - adaptive - sgd no converge con 152 - 32
# La combinación identity - adaptive - adam converge con 152 - 32
# La combinación logistic - constant - lbfgs no converge con 152 - 32
# La combinación logistic - constant - sgd converge con 152 - 32
# La combinación logistic - constant - adam converge con 152 - 32
# La combinación logistic - invscaling - lbfgs no converge con 152 - 32
# La combinación logistic - invscaling - sgd converge con 152 - 32
# La combinación logistic - invscaling - adam converge con 152 - 32
# La combinación logistic - adaptive - lbfgs no converge con 152 - 32
# La combinación logistic - adaptive - sgd converge con 152 - 32
# La combinación logistic - adaptive - adam converge con 152 - 32
# La combinación tanh - constant - lbfgs no converge con 152 - 32
# La combinación tanh - constant - sgd no converge con 152 - 32
# La combinación tanh - constant - adam no converge con 152 - 32
# La combinación tanh - invscaling - lbfgs no converge con 152 - 32
# La combinación tanh - invscaling - sgd converge con 152 - 32
# La combinación tanh - invscaling - adam converge con 152 - 32
# La combinación tanh - adaptive - lbfgs no converge con 152 - 32
# La combinación tanh - adaptive - sgd no converge con 152 - 32
# La combinación tanh - adaptive - adam no converge con 152 - 32
# La combinación relu - constant - lbfgs no converge con 152 - 32
# La combinación relu - constant - sgd no converge con 152 - 32
# La combinación relu - constant - adam no converge con 152 - 32
# La combinación relu - invscaling - lbfgs no converge con 152 - 32
# La combinación relu - invscaling - sgd converge con 152 - 32
# La combinación relu - invscaling - adam no converge con 152 - 32
# La combinación relu - adaptive - lbfgs no converge con 152 - 32
# La combinación relu - adaptive - sgd no converge con 152 - 32
# La combinación relu - adaptive - adam no converge con 152 - 32
# La combinación identity - constant - lbfgs converge con 152 - 62
# La combinación identity - constant - sgd no converge con 152 - 62
# La combinación identity - constant - adam converge con 152 - 62
# La combinación identity - invscaling - lbfgs converge con 152 - 62
# La combinación identity - invscaling - sgd converge con 152 - 62
# La combinación identity - invscaling - adam converge con 152 - 62
# La combinación identity - adaptive - lbfgs converge con 152 - 62
# La combinación identity - adaptive - sgd no converge con 152 - 62
# La combinación identity - adaptive - adam converge con 152 - 62
# La combinación logistic - constant - lbfgs no converge con 152 - 62
# La combinación logistic - constant - sgd converge con 152 - 62
# La combinación logistic - constant - adam converge con 152 - 62
# La combinación logistic - invscaling - lbfgs no converge con 152 - 62
# La combinación logistic - invscaling - sgd converge con 152 - 62
# La combinación logistic - invscaling - adam converge con 152 - 62
# La combinación logistic - adaptive - lbfgs converge con 152 - 62
# La combinación logistic - adaptive - sgd converge con 152 - 62
# La combinación logistic - adaptive - adam converge con 152 - 62
# La combinación tanh - constant - lbfgs no converge con 152 - 62
# La combinación tanh - constant - sgd no converge con 152 - 62
# La combinación tanh - constant - adam no converge con 152 - 62
# La combinación tanh - invscaling - lbfgs no converge con 152 - 62
# La combinación tanh - invscaling - sgd converge con 152 - 62
# La combinación tanh - invscaling - adam no converge con 152 - 62
# La combinación tanh - adaptive - lbfgs no converge con 152 - 62
# La combinación tanh - adaptive - sgd no converge con 152 - 62
# La combinación tanh - adaptive - adam converge con 152 - 62
# La combinación relu - constant - lbfgs no converge con 152 - 62
# La combinación relu - constant - sgd no converge con 152 - 62
# La combinación relu - constant - adam no converge con 152 - 62
# La combinación relu - invscaling - lbfgs no converge con 152 - 62
# La combinación relu - invscaling - sgd converge con 152 - 62
# La combinación relu - invscaling - adam no converge con 152 - 62
# La combinación relu - adaptive - lbfgs no converge con 152 - 62
# La combinación relu - adaptive - sgd no converge con 152 - 62
# La combinación relu - adaptive - adam no converge con 152 - 62
# La combinación identity - constant - lbfgs converge con 152 - 92
# La combinación identity - constant - sgd no converge con 152 - 92
# La combinación identity - constant - adam converge con 152 - 92
# La combinación identity - invscaling - lbfgs converge con 152 - 92
# La combinación identity - invscaling - sgd converge con 152 - 92
# La combinación identity - invscaling - adam converge con 152 - 92
# La combinación identity - adaptive - lbfgs converge con 152 - 92
# La combinación identity - adaptive - sgd no converge con 152 - 92
# La combinación identity - adaptive - adam converge con 152 - 92
# La combinación logistic - constant - lbfgs no converge con 152 - 92
# La combinación logistic - constant - sgd converge con 152 - 92
# La combinación logistic - constant - adam converge con 152 - 92
# La combinación logistic - invscaling - lbfgs no converge con 152 - 92
# La combinación logistic - invscaling - sgd converge con 152 - 92
# La combinación logistic - invscaling - adam converge con 152 - 92
# La combinación logistic - adaptive - lbfgs no converge con 152 - 92
# La combinación logistic - adaptive - sgd converge con 152 - 92
# La combinación logistic - adaptive - adam converge con 152 - 92
# La combinación tanh - constant - lbfgs no converge con 152 - 92
# La combinación tanh - constant - sgd no converge con 152 - 92
# La combinación tanh - constant - adam converge con 152 - 92
# La combinación tanh - invscaling - lbfgs no converge con 152 - 92
# La combinación tanh - invscaling - sgd converge con 152 - 92
# La combinación tanh - invscaling - adam converge con 152 - 92
# La combinación tanh - adaptive - lbfgs no converge con 152 - 92
# La combinación tanh - adaptive - sgd no converge con 152 - 92
# La combinación tanh - adaptive - adam converge con 152 - 92
# La combinación relu - constant - lbfgs no converge con 152 - 92
# La combinación relu - constant - sgd no converge con 152 - 92
# La combinación relu - constant - adam no converge con 152 - 92
# La combinación relu - invscaling - lbfgs no converge con 152 - 92
# La combinación relu - invscaling - sgd converge con 152 - 92
# La combinación relu - invscaling - adam no converge con 152 - 92
# La combinación relu - adaptive - lbfgs no converge con 152 - 92
# La combinación relu - adaptive - sgd no converge con 152 - 92
# La combinación relu - adaptive - adam no converge con 152 - 92
# La combinación identity - constant - lbfgs converge con 152 - 122
# La combinación identity - constant - sgd no converge con 152 - 122
# La combinación identity - constant - adam converge con 152 - 122
# La combinación identity - invscaling - lbfgs converge con 152 - 122
# La combinación identity - invscaling - sgd converge con 152 - 122
# La combinación identity - invscaling - adam converge con 152 - 122
# La combinación identity - adaptive - lbfgs converge con 152 - 122
# La combinación identity - adaptive - sgd no converge con 152 - 122
# La combinación identity - adaptive - adam converge con 152 - 122
# La combinación logistic - constant - lbfgs no converge con 152 - 122
# La combinación logistic - constant - sgd converge con 152 - 122
# La combinación logistic - constant - adam converge con 152 - 122
# La combinación logistic - invscaling - lbfgs no converge con 152 - 122
# La combinación logistic - invscaling - sgd converge con 152 - 122
# La combinación logistic - invscaling - adam converge con 152 - 122
# La combinación logistic - adaptive - lbfgs converge con 152 - 122
# La combinación logistic - adaptive - sgd converge con 152 - 122
# La combinación logistic - adaptive - adam converge con 152 - 122
# La combinación tanh - constant - lbfgs no converge con 152 - 122
# La combinación tanh - constant - sgd no converge con 152 - 122
# La combinación tanh - constant - adam converge con 152 - 122
# La combinación tanh - invscaling - lbfgs no converge con 152 - 122
# La combinación tanh - invscaling - sgd converge con 152 - 122
# La combinación tanh - invscaling - adam no converge con 152 - 122
# La combinación tanh - adaptive - lbfgs no converge con 152 - 122
# La combinación tanh - adaptive - sgd no converge con 152 - 122
# La combinación tanh - adaptive - adam no converge con 152 - 122
# La combinación relu - constant - lbfgs converge con 152 - 122
# La combinación relu - constant - sgd no converge con 152 - 122
# La combinación relu - constant - adam no converge con 152 - 122
# La combinación relu - invscaling - lbfgs no converge con 152 - 122
# La combinación relu - invscaling - sgd converge con 152 - 122
# La combinación relu - invscaling - adam no converge con 152 - 122
# La combinación relu - adaptive - lbfgs no converge con 152 - 122
# La combinación relu - adaptive - sgd no converge con 152 - 122
# La combinación relu - adaptive - adam no converge con 152 - 122
# La combinación identity - constant - lbfgs converge con 202 - 2
# La combinación identity - constant - sgd no converge con 202 - 2
# La combinación identity - constant - adam converge con 202 - 2
# La combinación identity - invscaling - lbfgs converge con 202 - 2
# La combinación identity - invscaling - sgd converge con 202 - 2
# La combinación identity - invscaling - adam converge con 202 - 2
# La combinación identity - adaptive - lbfgs converge con 202 - 2
# La combinación identity - adaptive - sgd no converge con 202 - 2
# La combinación identity - adaptive - adam converge con 202 - 2
# La combinación logistic - constant - lbfgs converge con 202 - 2
# La combinación logistic - constant - sgd converge con 202 - 2
# La combinación logistic - constant - adam no converge con 202 - 2
# La combinación logistic - invscaling - lbfgs no converge con 202 - 2
# La combinación logistic - invscaling - sgd converge con 202 - 2
# La combinación logistic - invscaling - adam no converge con 202 - 2
# La combinación logistic - adaptive - lbfgs no converge con 202 - 2
# La combinación logistic - adaptive - sgd converge con 202 - 2
# La combinación logistic - adaptive - adam no converge con 202 - 2
# La combinación tanh - constant - lbfgs no converge con 202 - 2
# La combinación tanh - constant - sgd no converge con 202 - 2
# La combinación tanh - constant - adam converge con 202 - 2
# La combinación tanh - invscaling - lbfgs no converge con 202 - 2
# La combinación tanh - invscaling - sgd converge con 202 - 2
# La combinación tanh - invscaling - adam converge con 202 - 2
# La combinación tanh - adaptive - lbfgs no converge con 202 - 2
# La combinación tanh - adaptive - sgd no converge con 202 - 2
# La combinación tanh - adaptive - adam converge con 202 - 2
# La combinación relu - constant - lbfgs no converge con 202 - 2
# La combinación relu - constant - sgd converge con 202 - 2
# La combinación relu - constant - adam no converge con 202 - 2
# La combinación relu - invscaling - lbfgs converge con 202 - 2
# La combinación relu - invscaling - sgd converge con 202 - 2
# La combinación relu - invscaling - adam no converge con 202 - 2
# La combinación relu - adaptive - lbfgs no converge con 202 - 2
# La combinación relu - adaptive - sgd no converge con 202 - 2
# La combinación relu - adaptive - adam no converge con 202 - 2
# La combinación identity - constant - lbfgs converge con 202 - 32
# La combinación identity - constant - sgd no converge con 202 - 32
# La combinación identity - constant - adam converge con 202 - 32
# La combinación identity - invscaling - lbfgs converge con 202 - 32
# La combinación identity - invscaling - sgd converge con 202 - 32
# La combinación identity - invscaling - adam converge con 202 - 32
# La combinación identity - adaptive - lbfgs converge con 202 - 32
# La combinación identity - adaptive - sgd no converge con 202 - 32
# La combinación identity - adaptive - adam converge con 202 - 32
# La combinación logistic - constant - lbfgs no converge con 202 - 32
# La combinación logistic - constant - sgd converge con 202 - 32
# La combinación logistic - constant - adam converge con 202 - 32
# La combinación logistic - invscaling - lbfgs no converge con 202 - 32
# La combinación logistic - invscaling - sgd converge con 202 - 32
# La combinación logistic - invscaling - adam converge con 202 - 32
# La combinación logistic - adaptive - lbfgs no converge con 202 - 32
# La combinación logistic - adaptive - sgd converge con 202 - 32
# La combinación logistic - adaptive - adam converge con 202 - 32
# La combinación tanh - constant - lbfgs no converge con 202 - 32
# La combinación tanh - constant - sgd no converge con 202 - 32
# La combinación tanh - constant - adam no converge con 202 - 32
# La combinación tanh - invscaling - lbfgs no converge con 202 - 32
# La combinación tanh - invscaling - sgd converge con 202 - 32
# La combinación tanh - invscaling - adam no converge con 202 - 32
# La combinación tanh - adaptive - lbfgs no converge con 202 - 32
# La combinación tanh - adaptive - sgd no converge con 202 - 32
# La combinación tanh - adaptive - adam no converge con 202 - 32
# La combinación relu - constant - lbfgs no converge con 202 - 32
# La combinación relu - constant - sgd no converge con 202 - 32
# La combinación relu - constant - adam no converge con 202 - 32
# La combinación relu - invscaling - lbfgs no converge con 202 - 32
# La combinación relu - invscaling - sgd converge con 202 - 32
# La combinación relu - invscaling - adam no converge con 202 - 32
# La combinación relu - adaptive - lbfgs no converge con 202 - 32
# La combinación relu - adaptive - sgd no converge con 202 - 32
# La combinación relu - adaptive - adam no converge con 202 - 32
# La combinación identity - constant - lbfgs converge con 202 - 62
# La combinación identity - constant - sgd no converge con 202 - 62
# La combinación identity - constant - adam converge con 202 - 62
# La combinación identity - invscaling - lbfgs converge con 202 - 62
# La combinación identity - invscaling - sgd converge con 202 - 62
# La combinación identity - invscaling - adam converge con 202 - 62
# La combinación identity - adaptive - lbfgs converge con 202 - 62
# La combinación identity - adaptive - sgd no converge con 202 - 62
# La combinación identity - adaptive - adam converge con 202 - 62
# La combinación logistic - constant - lbfgs no converge con 202 - 62
# La combinación logistic - constant - sgd converge con 202 - 62
# La combinación logistic - constant - adam converge con 202 - 62
# La combinación logistic - invscaling - lbfgs no converge con 202 - 62
# La combinación logistic - invscaling - sgd converge con 202 - 62
# La combinación logistic - invscaling - adam converge con 202 - 62
# La combinación logistic - adaptive - lbfgs no converge con 202 - 62
# La combinación logistic - adaptive - sgd converge con 202 - 62
# La combinación logistic - adaptive - adam converge con 202 - 62
# La combinación tanh - constant - lbfgs no converge con 202 - 62
# La combinación tanh - constant - sgd no converge con 202 - 62
# La combinación tanh - constant - adam no converge con 202 - 62
# La combinación tanh - invscaling - lbfgs no converge con 202 - 62
# La combinación tanh - invscaling - sgd converge con 202 - 62
# La combinación tanh - invscaling - adam converge con 202 - 62
# La combinación tanh - adaptive - lbfgs no converge con 202 - 62
# La combinación tanh - adaptive - sgd no converge con 202 - 62
# La combinación tanh - adaptive - adam no converge con 202 - 62
# La combinación relu - constant - lbfgs no converge con 202 - 62
# La combinación relu - constant - sgd no converge con 202 - 62
# La combinación relu - constant - adam no converge con 202 - 62
# La combinación relu - invscaling - lbfgs no converge con 202 - 62
# La combinación relu - invscaling - sgd converge con 202 - 62
# La combinación relu - invscaling - adam no converge con 202 - 62
# La combinación relu - adaptive - lbfgs no converge con 202 - 62
# La combinación relu - adaptive - sgd no converge con 202 - 62
# La combinación relu - adaptive - adam converge con 202 - 62
# La combinación identity - constant - lbfgs converge con 202 - 92
# La combinación identity - constant - sgd no converge con 202 - 92
# La combinación identity - constant - adam converge con 202 - 92
# La combinación identity - invscaling - lbfgs converge con 202 - 92
# La combinación identity - invscaling - sgd converge con 202 - 92
# La combinación identity - invscaling - adam converge con 202 - 92
# La combinación identity - adaptive - lbfgs converge con 202 - 92
# La combinación identity - adaptive - sgd no converge con 202 - 92
# La combinación identity - adaptive - adam converge con 202 - 92
# La combinación logistic - constant - lbfgs no converge con 202 - 92
# La combinación logistic - constant - sgd converge con 202 - 92
# La combinación logistic - constant - adam converge con 202 - 92
# La combinación logistic - invscaling - lbfgs no converge con 202 - 92
# La combinación logistic - invscaling - sgd converge con 202 - 92
# La combinación logistic - invscaling - adam converge con 202 - 92
# La combinación logistic - adaptive - lbfgs no converge con 202 - 92
# La combinación logistic - adaptive - sgd converge con 202 - 92
# La combinación logistic - adaptive - adam converge con 202 - 92
# La combinación tanh - constant - lbfgs no converge con 202 - 92
# La combinación tanh - constant - sgd no converge con 202 - 92
# La combinación tanh - constant - adam no converge con 202 - 92
# La combinación tanh - invscaling - lbfgs no converge con 202 - 92
# La combinación tanh - invscaling - sgd converge con 202 - 92
# La combinación tanh - invscaling - adam converge con 202 - 92
# La combinación tanh - adaptive - lbfgs no converge con 202 - 92
# La combinación tanh - adaptive - sgd no converge con 202 - 92
# La combinación tanh - adaptive - adam converge con 202 - 92
# La combinación relu - constant - lbfgs no converge con 202 - 92
# La combinación relu - constant - sgd no converge con 202 - 92
# La combinación relu - constant - adam no converge con 202 - 92
# La combinación relu - invscaling - lbfgs no converge con 202 - 92
# La combinación relu - invscaling - sgd converge con 202 - 92
# La combinación relu - invscaling - adam no converge con 202 - 92
# La combinación relu - adaptive - lbfgs no converge con 202 - 92
# La combinación relu - adaptive - sgd no converge con 202 - 92
# La combinación relu - adaptive - adam no converge con 202 - 92
# La combinación identity - constant - lbfgs converge con 202 - 122
# La combinación identity - constant - sgd no converge con 202 - 122
# La combinación identity - constant - adam converge con 202 - 122
# La combinación identity - invscaling - lbfgs converge con 202 - 122
# La combinación identity - invscaling - sgd converge con 202 - 122
# La combinación identity - invscaling - adam converge con 202 - 122
# La combinación identity - adaptive - lbfgs converge con 202 - 122
# La combinación identity - adaptive - sgd no converge con 202 - 122
# La combinación identity - adaptive - adam converge con 202 - 122
# La combinación logistic - constant - lbfgs no converge con 202 - 122
# La combinación logistic - constant - sgd converge con 202 - 122
# La combinación logistic - constant - adam converge con 202 - 122
# La combinación logistic - invscaling - lbfgs no converge con 202 - 122
# La combinación logistic - invscaling - sgd converge con 202 - 122
# La combinación logistic - invscaling - adam converge con 202 - 122
# La combinación logistic - adaptive - lbfgs no converge con 202 - 122
# La combinación logistic - adaptive - sgd converge con 202 - 122
# La combinación logistic - adaptive - adam converge con 202 - 122
# La combinación tanh - constant - lbfgs no converge con 202 - 122
# La combinación tanh - constant - sgd no converge con 202 - 122
# La combinación tanh - constant - adam converge con 202 - 122
# La combinación tanh - invscaling - lbfgs no converge con 202 - 122
# La combinación tanh - invscaling - sgd converge con 202 - 122
# La combinación tanh - invscaling - adam no converge con 202 - 122
# La combinación tanh - adaptive - lbfgs no converge con 202 - 122
# La combinación tanh - adaptive - sgd no converge con 202 - 122
# La combinación tanh - adaptive - adam converge con 202 - 122
# La combinación relu - constant - lbfgs no converge con 202 - 122
# La combinación relu - constant - sgd no converge con 202 - 122
# La combinación relu - constant - adam no converge con 202 - 122
# La combinación relu - invscaling - lbfgs no converge con 202 - 122
# La combinación relu - invscaling - sgd converge con 202 - 122
# La combinación relu - invscaling - adam no converge con 202 - 122
# La combinación relu - adaptive - lbfgs no converge con 202 - 122
# La combinación relu - adaptive - sgd no converge con 202 - 122
# La combinación relu - adaptive - adam no converge con 202 - 122

# %% [markdown]
# A continuación se presenta la tabla con los resultados para el mejores score resultante en la validación de las redes de la segunda capa escondida.

# %%
resul2 = pd.DataFrame(data=top_5, columns=['score','N', 'Función de Activación', 'Tasa de aprendizaje', 'Algoritmo'])
resul2 = resul2.sort_values(by=['score'], ascending=False)
resul2.head()
# Out:
#         score    N Función de Activación Tasa de aprendizaje Algoritmo
# 414  0.861527  202                  relu            adaptive      adam
# 276  0.855539  102                  relu          invscaling      adam
# 238  0.852545  102                  relu            constant      adam
# 165  0.847305   52                  relu            constant      adam
# 257  0.845060  102                  relu            constant      adam

# %% [markdown]
# Para una mejor visualización del comportamiento de cada uno de los parámetros estudiados, se presenta la siguiente gráfica que resume los resultados obtenidos para el caso en el que se usa el algoritmo "sgd" y el algoritmo "adam".

# %%
f = plt.figure(figsize=(18,6))
f.suptitle('Comparación de los parámetros seleccionados teniendo en cuenta los algoritmos en la segunda capa escondida', y=1.2, fontsize=16)

plot_args = [{'c': 'blue', 'linestyle': '-'},
             {'c': 'orange', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'red', 'linestyle': '-'},
             {'c': 'olive', 'linestyle': '-'},
             {'c': 'magenta', 'linestyle': '-'},
             {'c': 'black', 'linestyle': '--'},
             {'c': 'yellowgreen', 'linestyle': '--'},
             {'c': 'violet', 'linestyle': '--'},
             {'c': 'tomato', 'linestyle': '--'},
             {'c': 'navy', 'linestyle': '--'},
             {'c': 'brown', 'linestyle': '--'}]

cont=1
args = 0
labels = []
for alg in algoritmo:
  ax = plt.subplot(2,2,cont)
  ax.set_title(r'$\bf{Algoritmo~}$'+r'$\bf{}$'.format(alg), fontsize=14)
  ax.set_ylabel('Score')
  ax.set_xlabel('Número de neuronas (N)')
  ax.grid(linestyle='--',b=True, which='major')
  for act in activacion:
    for rate in tasas_aprendizaje:
      temp = resul2.loc[(resul2['Función de Activación']==act) & (resul2['Tasa de aprendizaje']==rate) & (resul2['Algoritmo']==alg)]
      temp = temp.sort_values(by=['N'], ascending=True)
      ax.plot(temp['N'].values, temp['score'].values, **plot_args[args])
      labels.append(r'$\bf{act:}$ ' + act + ' + ' + r'$\bf{tasa:}$ ' + rate)
      if args < 11:
        args = args + 1
      else:
        args = 0

  f.legend(ax.get_lines(), labels, ncol=3, loc="lower center", bbox_to_anchor=(0.4, 0.9))
  cont = cont+1

# %% [markdown]
# Teniendo en cuenta la combinación de parámetros con el porcentaje de precisión más alto, se procede a correr el modelo de perceptrón multinivel para los datos de prueba, el modelo de entrenamiento del clasificador es presentado a continuación.

# %%
# Se presentan los parámetros apropiados
N2 = resul2.iloc[0,:]['N'] # El número de neuronas apropiado obtenido previamente
activation = resul2.iloc[0,:]['Función de Activación'] # La función de activación
learning_rate = resul2.iloc[0,:]['Tasa de aprendizaje'] # Tasa de aprendizaje
algor = resul2.iloc[0,:]['Algoritmo'] # Algoritmo seleccionado

MLP_2L = MLPClassifier(hidden_layer_sizes=(N,N2,),activation=activation, learning_rate=learning_rate, solver=algor,max_iter=1200)
Hidden_2L = MLP_2L.fit(x_train, y_train)

# %% [markdown]
# La precisión del modelo seleccionado es evaluada en la siguiente entrada de código.

# %%
result_2L = Hidden_2L.score(x_test, y_test)
print('El modelo con dos capas tiene una precisión del {:.2f}%'.format(result_2L*100))
# Out:
# El modelo con dos capas tiene una precisión del 85.21%

# %% [markdown]
# Para complementar la validación del modelo, se presenta la matriz de confusión, donde se puede detallar el porcentaje normalizado de los aciertos y desaciertos del modelo para cada una de las variables a clasificar. En este caso la diagonal corresponde al porcentaje normalizado del acierto de la predicción, mientras que los elementos fuera de la diagonal representan el porcentaje de desacierto para cada variable.

# %%
class_names = ['jazz and blues','soul and reggae']
plot_confusion_matrix(Hidden_2L, x_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues, normalize = 'true')
plt.title('Matriz de confusiones normalizada para el modelo de 2 capas escondidas', fontsize = 14)
plt.show()

# %% [markdown]
# ## Red neural con 3 capas escondidas
#
# En este caso, al igual que el caso anterior, se asumirá que la segunda capa tiene el mismo número de neuronas encontrado en el caso anterior. Esto se hace nuevamente con el fin de reducir el trabajo computacional, y se recalca que posiblemente esta no es el número de neuronas óptimo para este modelo.

# %%
n1 = 250
n2 = 152
n3 = 152
step1 = 50
step2 = 50
step3 = 30
top_5 = []
u=0
for i in range(2, n1, step):
  for m in range(2, n2, step2):
    for n in range(2, n3, step3):
      for j in activacion:
        for k in tasas_aprendizaje:
          for l in algoritmo:       
            try:
              MLP = MLPClassifier(hidden_layer_sizes=(i,m,n,),activation=j, learning_rate=k, solver=l,max_iter=200)      
              with warnings.catch_warnings():  
                warnings.filterwarnings("error", category=ConvergenceWarning,
                                        module="sklearn")
                clf = MLP.fit(x_train1, y_train1)
                score =clf.score(x_test1, y_test1)
                celda = [score, i, j, k, l]
                top_5.append(celda) 
                mensaje = 'La combinación ' + j + ' - ' + k + ' - ' + l + ' converge con ' + str(i) + ' - ' + str(m)
              print(mensaje)
            except:
              mensaje = 'La combinación ' + j + ' - ' + k + ' - ' + l + ' no converge con ' + str(i) + ' - ' + str(m)
              print(mensaje)
# Out:
# La combinación identity - constant - lbfgs converge con 2 - 2
# La combinación identity - constant - sgd no converge con 2 - 2
# La combinación identity - constant - adam converge con 2 - 2
# La combinación identity - invscaling - lbfgs converge con 2 - 2
# La combinación identity - invscaling - sgd converge con 2 - 2
# La combinación identity - invscaling - adam converge con 2 - 2
# La combinación identity - adaptive - lbfgs converge con 2 - 2
# La combinación identity - adaptive - sgd no converge con 2 - 2
# La combinación identity - adaptive - adam no converge con 2 - 2
# La combinación logistic - constant - lbfgs converge con 2 - 2
# La combinación logistic - constant - sgd converge con 2 - 2
# La combinación logistic - constant - adam converge con 2 - 2
# La combinación logistic - invscaling - lbfgs converge con 2 - 2
# La combinación logistic - invscaling - sgd converge con 2 - 2
# La combinación logistic - invscaling - adam converge con 2 - 2
# La combinación logistic - adaptive - lbfgs converge con 2 - 2
# La combinación logistic - adaptive - sgd converge con 2 - 2
# La combinación logistic - adaptive - adam converge con 2 - 2
# La combinación tanh - constant - lbfgs no converge con 2 - 2
# La combinación tanh - constant - sgd converge con 2 - 2
# La combinación tanh - constant - adam converge con 2 - 2
# La combinación tanh - invscaling - lbfgs no converge con 2 - 2
# La combinación tanh - invscaling - sgd converge con 2 - 2
# La combinación tanh - invscaling - adam no converge con 2 - 2
# La combinación tanh - adaptive - lbfgs no converge con 2 - 2
# La combinación tanh - adaptive - sgd converge con 2 - 2
# La combinación tanh - adaptive - adam no converge con 2 - 2
# La combinación relu - constant - lbfgs converge con 2 - 2
# La combinación relu - constant - sgd converge con 2 - 2
# La combinación relu - constant - adam no converge con 2 - 2
# La combinación relu - invscaling - lbfgs converge con 2 - 2
# La combinación relu - invscaling - sgd converge con 2 - 2
# La combinación relu - invscaling - adam no converge con 2 - 2
# La combinación relu - adaptive - lbfgs converge con 2 - 2
# La combinación relu - adaptive - sgd converge con 2 - 2
# La combinación relu - adaptive - adam no converge con 2 - 2
# La combinación identity - constant - lbfgs no converge con 2 - 2
# La combinación identity - constant - sgd no converge con 2 - 2
# La combinación identity - constant - adam converge con 2 - 2
# La combinación identity - invscaling - lbfgs converge con 2 - 2
# La combinación identity - invscaling - sgd converge con 2 - 2
# La combinación identity - invscaling - adam converge con 2 - 2
# La combinación identity - adaptive - lbfgs no converge con 2 - 2
# La combinación identity - adaptive - sgd no converge con 2 - 2
# La combinación identity - adaptive - adam converge con 2 - 2
# La combinación logistic - constant - lbfgs converge con 2 - 2
# La combinación logistic - constant - sgd converge con 2 - 2
# La combinación logistic - constant - adam converge con 2 - 2
# La combinación logistic - invscaling - lbfgs no converge con 2 - 2
# La combinación logistic - invscaling - sgd converge con 2 - 2
# La combinación logistic - invscaling - adam no converge con 2 - 2
# La combinación logistic - adaptive - lbfgs converge con 2 - 2
# La combinación logistic - adaptive - sgd converge con 2 - 2
# La combinación logistic - adaptive - adam converge con 2 - 2
# La combinación tanh - constant - lbfgs no converge con 2 - 2
# La combinación tanh - constant - sgd no converge con 2 - 2
# La combinación tanh - constant - adam converge con 2 - 2
# La combinación tanh - invscaling - lbfgs no converge con 2 - 2
# La combinación tanh - invscaling - sgd converge con 2 - 2
# La combinación tanh - invscaling - adam converge con 2 - 2
# La combinación tanh - adaptive - lbfgs converge con 2 - 2
# La combinación tanh - adaptive - sgd no converge con 2 - 2
# La combinación tanh - adaptive - adam converge con 2 - 2
# La combinación relu - constant - lbfgs converge con 2 - 2
# La combinación relu - constant - sgd converge con 2 - 2
# La combinación relu - constant - adam converge con 2 - 2
# La combinación relu - invscaling - lbfgs converge con 2 - 2
# La combinación relu - invscaling - sgd converge con 2 - 2
# La combinación relu - invscaling - adam no converge con 2 - 2
# La combinación relu - adaptive - lbfgs no converge con 2 - 2
# La combinación relu - adaptive - sgd converge con 2 - 2
# La combinación relu - adaptive - adam converge con 2 - 2
# La combinación identity - constant - lbfgs no converge con 2 - 2
# La combinación identity - constant - sgd no converge con 2 - 2
# La combinación identity - constant - adam converge con 2 - 2
# La combinación identity - invscaling - lbfgs no converge con 2 - 2
# La combinación identity - invscaling - sgd converge con 2 - 2
# La combinación identity - invscaling - adam converge con 2 - 2
# La combinación identity - adaptive - lbfgs converge con 2 - 2
# La combinación identity - adaptive - sgd no converge con 2 - 2
# La combinación identity - adaptive - adam converge con 2 - 2
# La combinación logistic - constant - lbfgs converge con 2 - 2
# La combinación logistic - constant - sgd converge con 2 - 2
# La combinación logistic - constant - adam no converge con 2 - 2
# La combinación logistic - invscaling - lbfgs converge con 2 - 2
# La combinación logistic - invscaling - sgd converge con 2 - 2
# La combinación logistic - invscaling - adam converge con 2 - 2
# La combinación logistic - adaptive - lbfgs converge con 2 - 2
# La combinación logistic - adaptive - sgd converge con 2 - 2
# La combinación logistic - adaptive - adam no converge con 2 - 2
# La combinación tanh - constant - lbfgs no converge con 2 - 2
# La combinación tanh - constant - sgd no converge con 2 - 2
# La combinación tanh - constant - adam converge con 2 - 2
# La combinación tanh - invscaling - lbfgs no converge con 2 - 2
# La combinación tanh - invscaling - sgd converge con 2 - 2
# La combinación tanh - invscaling - adam converge con 2 - 2
# La combinación tanh - adaptive - lbfgs no converge con 2 - 2
# La combinación tanh - adaptive - sgd converge con 2 - 2
# La combinación tanh - adaptive - adam converge con 2 - 2
# La combinación relu - constant - lbfgs converge con 2 - 2
# La combinación relu - constant - sgd no converge con 2 - 2
# La combinación relu - constant - adam converge con 2 - 2
# La combinación relu - invscaling - lbfgs converge con 2 - 2
# La combinación relu - invscaling - sgd converge con 2 - 2
# La combinación relu - invscaling - adam converge con 2 - 2
# La combinación relu - adaptive - lbfgs no converge con 2 - 2
# La combinación relu - adaptive - sgd no converge con 2 - 2
# La combinación relu - adaptive - adam converge con 2 - 2
# La combinación identity - constant - lbfgs converge con 2 - 2
# La combinación identity - constant - sgd no converge con 2 - 2
# La combinación identity - constant - adam converge con 2 - 2
# La combinación identity - invscaling - lbfgs no converge con 2 - 2
# La combinación identity - invscaling - sgd converge con 2 - 2
# La combinación identity - invscaling - adam converge con 2 - 2
# La combinación identity - adaptive - lbfgs converge con 2 - 2
# La combinación identity - adaptive - sgd no converge con 2 - 2
# La combinación identity - adaptive - adam converge con 2 - 2
# La combinación logistic - constant - lbfgs converge con 2 - 2
# La combinación logistic - constant - sgd converge con 2 - 2
# La combinación logistic - constant - adam converge con 2 - 2
# La combinación logistic - invscaling - lbfgs converge con 2 - 2
# La combinación logistic - invscaling - sgd converge con 2 - 2
# La combinación logistic - invscaling - adam no converge con 2 - 2
# La combinación logistic - adaptive - lbfgs converge con 2 - 2
# La combinación logistic - adaptive - sgd converge con 2 - 2
# La combinación logistic - adaptive - adam no converge con 2 - 2
# La combinación tanh - constant - lbfgs no converge con 2 - 2
# La combinación tanh - constant - sgd no converge con 2 - 2
# La combinación tanh - constant - adam converge con 2 - 2
# La combinación tanh - invscaling - lbfgs no converge con 2 - 2
# La combinación tanh - invscaling - sgd converge con 2 - 2
# La combinación tanh - invscaling - adam converge con 2 - 2
# La combinación tanh - adaptive - lbfgs no converge con 2 - 2
# La combinación tanh - adaptive - sgd converge con 2 - 2
# La combinación tanh - adaptive - adam converge con 2 - 2
# La combinación relu - constant - lbfgs no converge con 2 - 2
# La combinación relu - constant - sgd no converge con 2 - 2
# La combinación relu - constant - adam converge con 2 - 2
# La combinación relu - invscaling - lbfgs no converge con 2 - 2
# La combinación relu - invscaling - sgd converge con 2 - 2
# La combinación relu - invscaling - adam no converge con 2 - 2
# La combinación relu - adaptive - lbfgs converge con 2 - 2
# La combinación relu - adaptive - sgd no converge con 2 - 2
# La combinación relu - adaptive - adam converge con 2 - 2
# La combinación identity - constant - lbfgs converge con 2 - 2
# La combinación identity - constant - sgd no converge con 2 - 2
# La combinación identity - constant - adam converge con 2 - 2
# La combinación identity - invscaling - lbfgs no converge con 2 - 2
# La combinación identity - invscaling - sgd converge con 2 - 2
# La combinación identity - invscaling - adam converge con 2 - 2
# La combinación identity - adaptive - lbfgs no converge con 2 - 2
# La combinación identity - adaptive - sgd no converge con 2 - 2
# La combinación identity - adaptive - adam converge con 2 - 2
# La combinación logistic - constant - lbfgs converge con 2 - 2
# La combinación logistic - constant - sgd converge con 2 - 2
# La combinación logistic - constant - adam no converge con 2 - 2
# La combinación logistic - invscaling - lbfgs converge con 2 - 2
# La combinación logistic - invscaling - sgd converge con 2 - 2
# La combinación logistic - invscaling - adam no converge con 2 - 2
# La combinación logistic - adaptive - lbfgs converge con 2 - 2
# La combinación logistic - adaptive - sgd converge con 2 - 2
# La combinación logistic - adaptive - adam converge con 2 - 2
# La combinación tanh - constant - lbfgs no converge con 2 - 2
# La combinación tanh - constant - sgd converge con 2 - 2
# La combinación tanh - constant - adam converge con 2 - 2
# La combinación tanh - invscaling - lbfgs no converge con 2 - 2
# La combinación tanh - invscaling - sgd converge con 2 - 2
# La combinación tanh - invscaling - adam converge con 2 - 2
# La combinación tanh - adaptive - lbfgs no converge con 2 - 2
# La combinación tanh - adaptive - sgd converge con 2 - 2
# La combinación tanh - adaptive - adam no converge con 2 - 2
# La combinación relu - constant - lbfgs converge con 2 - 2
# La combinación relu - constant - sgd no converge con 2 - 2
# La combinación relu - constant - adam converge con 2 - 2
# La combinación relu - invscaling - lbfgs converge con 2 - 2
# La combinación relu - invscaling - sgd converge con 2 - 2
# La combinación relu - invscaling - adam converge con 2 - 2
# La combinación relu - adaptive - lbfgs converge con 2 - 2
# La combinación relu - adaptive - sgd converge con 2 - 2
# La combinación relu - adaptive - adam no converge con 2 - 2
# La combinación identity - constant - lbfgs no converge con 2 - 52
# La combinación identity - constant - sgd no converge con 2 - 52
# La combinación identity - constant - adam converge con 2 - 52
# La combinación identity - invscaling - lbfgs no converge con 2 - 52
# La combinación identity - invscaling - sgd converge con 2 - 52
# La combinación identity - invscaling - adam converge con 2 - 52
# La combinación identity - adaptive - lbfgs converge con 2 - 52
# La combinación identity - adaptive - sgd no converge con 2 - 52
# La combinación identity - adaptive - adam converge con 2 - 52
# La combinación logistic - constant - lbfgs converge con 2 - 52
# La combinación logistic - constant - sgd converge con 2 - 52
# La combinación logistic - constant - adam no converge con 2 - 52
# La combinación logistic - invscaling - lbfgs converge con 2 - 52
# La combinación logistic - invscaling - sgd converge con 2 - 52
# La combinación logistic - invscaling - adam no converge con 2 - 52
# La combinación logistic - adaptive - lbfgs converge con 2 - 52
# La combinación logistic - adaptive - sgd converge con 2 - 52
# La combinación logistic - adaptive - adam converge con 2 - 52
# La combinación tanh - constant - lbfgs no converge con 2 - 52
# La combinación tanh - constant - sgd no converge con 2 - 52
# La combinación tanh - constant - adam converge con 2 - 52
# La combinación tanh - invscaling - lbfgs no converge con 2 - 52
# La combinación tanh - invscaling - sgd converge con 2 - 52
# La combinación tanh - invscaling - adam converge con 2 - 52
# La combinación tanh - adaptive - lbfgs no converge con 2 - 52
# La combinación tanh - adaptive - sgd no converge con 2 - 52
# La combinación tanh - adaptive - adam no converge con 2 - 52
# La combinación relu - constant - lbfgs converge con 2 - 52
# La combinación relu - constant - sgd converge con 2 - 52
# La combinación relu - constant - adam converge con 2 - 52
# La combinación relu - invscaling - lbfgs converge con 2 - 52
# La combinación relu - invscaling - sgd converge con 2 - 52
# La combinación relu - invscaling - adam converge con 2 - 52
# La combinación relu - adaptive - lbfgs converge con 2 - 52
# La combinación relu - adaptive - sgd converge con 2 - 52
# La combinación relu - adaptive - adam no converge con 2 - 52
# La combinación identity - constant - lbfgs no converge con 2 - 52
# La combinación identity - constant - sgd no converge con 2 - 52
# La combinación identity - constant - adam converge con 2 - 52
# La combinación identity - invscaling - lbfgs converge con 2 - 52
# La combinación identity - invscaling - sgd converge con 2 - 52
# La combinación identity - invscaling - adam converge con 2 - 52
# La combinación identity - adaptive - lbfgs no converge con 2 - 52
# La combinación identity - adaptive - sgd no converge con 2 - 52
# La combinación identity - adaptive - adam converge con 2 - 52
# La combinación logistic - constant - lbfgs converge con 2 - 52
# La combinación logistic - constant - sgd converge con 2 - 52
# La combinación logistic - constant - adam converge con 2 - 52
# La combinación logistic - invscaling - lbfgs converge con 2 - 52
# La combinación logistic - invscaling - sgd converge con 2 - 52
# La combinación logistic - invscaling - adam converge con 2 - 52
# La combinación logistic - adaptive - lbfgs converge con 2 - 52
# La combinación logistic - adaptive - sgd converge con 2 - 52
# La combinación logistic - adaptive - adam converge con 2 - 52
# La combinación tanh - constant - lbfgs no converge con 2 - 52
# La combinación tanh - constant - sgd no converge con 2 - 52
# La combinación tanh - constant - adam converge con 2 - 52
# La combinación tanh - invscaling - lbfgs no converge con 2 - 52
# La combinación tanh - invscaling - sgd converge con 2 - 52
# La combinación tanh - invscaling - adam no converge con 2 - 52
# La combinación tanh - adaptive - lbfgs no converge con 2 - 52
# La combinación tanh - adaptive - sgd no converge con 2 - 52
# La combinación tanh - adaptive - adam converge con 2 - 52
# La combinación relu - constant - lbfgs no converge con 2 - 52
# La combinación relu - constant - sgd no converge con 2 - 52
# La combinación relu - constant - adam converge con 2 - 52
# La combinación relu - invscaling - lbfgs no converge con 2 - 52
# La combinación relu - invscaling - sgd converge con 2 - 52
# La combinación relu - invscaling - adam converge con 2 - 52
# La combinación relu - adaptive - lbfgs converge con 2 - 52
# La combinación relu - adaptive - sgd converge con 2 - 52
# La combinación relu - adaptive - adam converge con 2 - 52
# La combinación identity - constant - lbfgs no converge con 2 - 52
# La combinación identity - constant - sgd no converge con 2 - 52
# La combinación identity - constant - adam converge con 2 - 52
# La combinación identity - invscaling - lbfgs converge con 2 - 52
# La combinación identity - invscaling - sgd converge con 2 - 52
# La combinación identity - invscaling - adam converge con 2 - 52
# La combinación identity - adaptive - lbfgs no converge con 2 - 52
# La combinación identity - adaptive - sgd no converge con 2 - 52
# La combinación identity - adaptive - adam converge con 2 - 52
# La combinación logistic - constant - lbfgs converge con 2 - 52
# La combinación logistic - constant - sgd converge con 2 - 52
# La combinación logistic - constant - adam converge con 2 - 52
# La combinación logistic - invscaling - lbfgs converge con 2 - 52
# La combinación logistic - invscaling - sgd converge con 2 - 52
# La combinación logistic - invscaling - adam no converge con 2 - 52
# La combinación logistic - adaptive - lbfgs converge con 2 - 52
# La combinación logistic - adaptive - sgd converge con 2 - 52
# La combinación logistic - adaptive - adam converge con 2 - 52
# La combinación tanh - constant - lbfgs no converge con 2 - 52
# La combinación tanh - constant - sgd no converge con 2 - 52
# La combinación tanh - constant - adam converge con 2 - 52
# La combinación tanh - invscaling - lbfgs no converge con 2 - 52
# La combinación tanh - invscaling - sgd converge con 2 - 52
# La combinación tanh - invscaling - adam converge con 2 - 52
# La combinación tanh - adaptive - lbfgs no converge con 2 - 52
# La combinación tanh - adaptive - sgd no converge con 2 - 52
# La combinación tanh - adaptive - adam converge con 2 - 52
# La combinación relu - constant - lbfgs no converge con 2 - 52
# La combinación relu - constant - sgd no converge con 2 - 52
# La combinación relu - constant - adam converge con 2 - 52
# La combinación relu - invscaling - lbfgs no converge con 2 - 52
# La combinación relu - invscaling - sgd converge con 2 - 52
# La combinación relu - invscaling - adam converge con 2 - 52
# La combinación relu - adaptive - lbfgs no converge con 2 - 52
# La combinación relu - adaptive - sgd converge con 2 - 52
# La combinación relu - adaptive - adam converge con 2 - 52
# La combinación identity - constant - lbfgs no converge con 2 - 52
# La combinación identity - constant - sgd no converge con 2 - 52
# La combinación identity - constant - adam converge con 2 - 52
# La combinación identity - invscaling - lbfgs no converge con 2 - 52
# La combinación identity - invscaling - sgd converge con 2 - 52
# La combinación identity - invscaling - adam converge con 2 - 52
# La combinación identity - adaptive - lbfgs converge con 2 - 52
# La combinación identity - adaptive - sgd no converge con 2 - 52
# La combinación identity - adaptive - adam converge con 2 - 52
# La combinación logistic - constant - lbfgs converge con 2 - 52
# La combinación logistic - constant - sgd converge con 2 - 52
# La combinación logistic - constant - adam no converge con 2 - 52
# La combinación logistic - invscaling - lbfgs converge con 2 - 52
# La combinación logistic - invscaling - sgd converge con 2 - 52
# La combinación logistic - invscaling - adam no converge con 2 - 52
# La combinación logistic - adaptive - lbfgs converge con 2 - 52
# La combinación logistic - adaptive - sgd converge con 2 - 52
# La combinación logistic - adaptive - adam converge con 2 - 52
# La combinación tanh - constant - lbfgs no converge con 2 - 52
# La combinación tanh - constant - sgd no converge con 2 - 52
# La combinación tanh - constant - adam converge con 2 - 52
# La combinación tanh - invscaling - lbfgs no converge con 2 - 52
# La combinación tanh - invscaling - sgd converge con 2 - 52
# La combinación tanh - invscaling - adam converge con 2 - 52
# La combinación tanh - adaptive - lbfgs no converge con 2 - 52
# La combinación tanh - adaptive - sgd converge con 2 - 52
# La combinación tanh - adaptive - adam converge con 2 - 52
# La combinación relu - constant - lbfgs converge con 2 - 52
# La combinación relu - constant - sgd converge con 2 - 52
# La combinación relu - constant - adam converge con 2 - 52
# La combinación relu - invscaling - lbfgs no converge con 2 - 52
# La combinación relu - invscaling - sgd converge con 2 - 52
# La combinación relu - invscaling - adam converge con 2 - 52
# La combinación relu - adaptive - lbfgs converge con 2 - 52
# La combinación relu - adaptive - sgd no converge con 2 - 52
# La combinación relu - adaptive - adam converge con 2 - 52
# La combinación identity - constant - lbfgs converge con 2 - 52
# La combinación identity - constant - sgd no converge con 2 - 52
# La combinación identity - constant - adam converge con 2 - 52
# La combinación identity - invscaling - lbfgs no converge con 2 - 52
# La combinación identity - invscaling - sgd converge con 2 - 52
# La combinación identity - invscaling - adam converge con 2 - 52
# La combinación identity - adaptive - lbfgs converge con 2 - 52
# La combinación identity - adaptive - sgd no converge con 2 - 52
# La combinación identity - adaptive - adam converge con 2 - 52
# La combinación logistic - constant - lbfgs converge con 2 - 52
# La combinación logistic - constant - sgd converge con 2 - 52
# La combinación logistic - constant - adam converge con 2 - 52
# La combinación logistic - invscaling - lbfgs converge con 2 - 52
# La combinación logistic - invscaling - sgd converge con 2 - 52
# La combinación logistic - invscaling - adam converge con 2 - 52
# La combinación logistic - adaptive - lbfgs converge con 2 - 52
# La combinación logistic - adaptive - sgd converge con 2 - 52
# La combinación logistic - adaptive - adam converge con 2 - 52
# La combinación tanh - constant - lbfgs no converge con 2 - 52
# La combinación tanh - constant - sgd no converge con 2 - 52
# La combinación tanh - constant - adam converge con 2 - 52
# La combinación tanh - invscaling - lbfgs no converge con 2 - 52
# La combinación tanh - invscaling - sgd converge con 2 - 52
# La combinación tanh - invscaling - adam converge con 2 - 52
# La combinación tanh - adaptive - lbfgs no converge con 2 - 52
# La combinación tanh - adaptive - sgd no converge con 2 - 52
# La combinación tanh - adaptive - adam converge con 2 - 52
# La combinación relu - constant - lbfgs no converge con 2 - 52
# La combinación relu - constant - sgd no converge con 2 - 52
# La combinación relu - constant - adam converge con 2 - 52
# La combinación relu - invscaling - lbfgs converge con 2 - 52
# La combinación relu - invscaling - sgd converge con 2 - 52
# La combinación relu - invscaling - adam converge con 2 - 52
# La combinación relu - adaptive - lbfgs converge con 2 - 52
# La combinación relu - adaptive - sgd no converge con 2 - 52
# La combinación relu - adaptive - adam converge con 2 - 52
# La combinación identity - constant - lbfgs converge con 2 - 102
# La combinación identity - constant - sgd no converge con 2 - 102
# La combinación identity - constant - adam converge con 2 - 102
# La combinación identity - invscaling - lbfgs no converge con 2 - 102
# La combinación identity - invscaling - sgd converge con 2 - 102
# La combinación identity - invscaling - adam converge con 2 - 102
# La combinación identity - adaptive - lbfgs converge con 2 - 102
# La combinación identity - adaptive - sgd no converge con 2 - 102
# La combinación identity - adaptive - adam converge con 2 - 102
# La combinación logistic - constant - lbfgs converge con 2 - 102
# La combinación logistic - constant - sgd converge con 2 - 102
# La combinación logistic - constant - adam no converge con 2 - 102
# La combinación logistic - invscaling - lbfgs converge con 2 - 102
# La combinación logistic - invscaling - sgd converge con 2 - 102
# La combinación logistic - invscaling - adam no converge con 2 - 102
# La combinación logistic - adaptive - lbfgs converge con 2 - 102
# La combinación logistic - adaptive - sgd converge con 2 - 102
# La combinación logistic - adaptive - adam converge con 2 - 102
# La combinación tanh - constant - lbfgs no converge con 2 - 102
# La combinación tanh - constant - sgd no converge con 2 - 102
# La combinación tanh - constant - adam converge con 2 - 102
# La combinación tanh - invscaling - lbfgs no converge con 2 - 102
# La combinación tanh - invscaling - sgd converge con 2 - 102
# La combinación tanh - invscaling - adam converge con 2 - 102
# La combinación tanh - adaptive - lbfgs no converge con 2 - 102
# La combinación tanh - adaptive - sgd no converge con 2 - 102
# La combinación tanh - adaptive - adam converge con 2 - 102
# La combinación relu - constant - lbfgs no converge con 2 - 102
# La combinación relu - constant - sgd no converge con 2 - 102
# La combinación relu - constant - adam converge con 2 - 102
# La combinación relu - invscaling - lbfgs converge con 2 - 102
# La combinación relu - invscaling - sgd converge con 2 - 102
# La combinación relu - invscaling - adam converge con 2 - 102
# La combinación relu - adaptive - lbfgs converge con 2 - 102
# La combinación relu - adaptive - sgd no converge con 2 - 102
# La combinación relu - adaptive - adam converge con 2 - 102
# La combinación identity - constant - lbfgs no converge con 2 - 102
# La combinación identity - constant - sgd no converge con 2 - 102
# La combinación identity - constant - adam converge con 2 - 102
# La combinación identity - invscaling - lbfgs no converge con 2 - 102
# La combinación identity - invscaling - sgd converge con 2 - 102
# La combinación identity - invscaling - adam converge con 2 - 102
# La combinación identity - adaptive - lbfgs converge con 2 - 102
# La combinación identity - adaptive - sgd no converge con 2 - 102
# La combinación identity - adaptive - adam converge con 2 - 102
# La combinación logistic - constant - lbfgs converge con 2 - 102
# La combinación logistic - constant - sgd converge con 2 - 102
# La combinación logistic - constant - adam converge con 2 - 102
# La combinación logistic - invscaling - lbfgs converge con 2 - 102
# La combinación logistic - invscaling - sgd converge con 2 - 102
# La combinación logistic - invscaling - adam converge con 2 - 102
# La combinación logistic - adaptive - lbfgs converge con 2 - 102
# La combinación logistic - adaptive - sgd converge con 2 - 102
# La combinación logistic - adaptive - adam converge con 2 - 102
# La combinación tanh - constant - lbfgs no converge con 2 - 102
# La combinación tanh - constant - sgd no converge con 2 - 102
# La combinación tanh - constant - adam converge con 2 - 102
# La combinación tanh - invscaling - lbfgs no converge con 2 - 102
# La combinación tanh - invscaling - sgd converge con 2 - 102
# La combinación tanh - invscaling - adam converge con 2 - 102
# La combinación tanh - adaptive - lbfgs no converge con 2 - 102
# La combinación tanh - adaptive - sgd no converge con 2 - 102
# La combinación tanh - adaptive - adam no converge con 2 - 102
# La combinación relu - constant - lbfgs no converge con 2 - 102
# La combinación relu - constant - sgd converge con 2 - 102
# La combinación relu - constant - adam no converge con 2 - 102
# La combinación relu - invscaling - lbfgs no converge con 2 - 102
# La combinación relu - invscaling - sgd converge con 2 - 102
# La combinación relu - invscaling - adam converge con 2 - 102
# La combinación relu - adaptive - lbfgs no converge con 2 - 102
# La combinación relu - adaptive - sgd no converge con 2 - 102
# La combinación relu - adaptive - adam converge con 2 - 102
# La combinación identity - constant - lbfgs no converge con 2 - 102
# La combinación identity - constant - sgd no converge con 2 - 102
# La combinación identity - constant - adam converge con 2 - 102
# La combinación identity - invscaling - lbfgs no converge con 2 - 102
# La combinación identity - invscaling - sgd converge con 2 - 102
# La combinación identity - invscaling - adam converge con 2 - 102
# La combinación identity - adaptive - lbfgs converge con 2 - 102
# La combinación identity - adaptive - sgd no converge con 2 - 102
# La combinación identity - adaptive - adam converge con 2 - 102
# La combinación logistic - constant - lbfgs converge con 2 - 102
# La combinación logistic - constant - sgd converge con 2 - 102
# La combinación logistic - constant - adam converge con 2 - 102
# La combinación logistic - invscaling - lbfgs converge con 2 - 102
# La combinación logistic - invscaling - sgd converge con 2 - 102
# La combinación logistic - invscaling - adam converge con 2 - 102
# La combinación logistic - adaptive - lbfgs converge con 2 - 102
# La combinación logistic - adaptive - sgd converge con 2 - 102
# La combinación logistic - adaptive - adam converge con 2 - 102
# La combinación tanh - constant - lbfgs no converge con 2 - 102
# La combinación tanh - constant - sgd no converge con 2 - 102
# La combinación tanh - constant - adam converge con 2 - 102
# La combinación tanh - invscaling - lbfgs no converge con 2 - 102
# La combinación tanh - invscaling - sgd converge con 2 - 102
# La combinación tanh - invscaling - adam converge con 2 - 102
# La combinación tanh - adaptive - lbfgs no converge con 2 - 102
# La combinación tanh - adaptive - sgd no converge con 2 - 102
# La combinación tanh - adaptive - adam converge con 2 - 102
# La combinación relu - constant - lbfgs converge con 2 - 102
# La combinación relu - constant - sgd no converge con 2 - 102
# La combinación relu - constant - adam converge con 2 - 102
# La combinación relu - invscaling - lbfgs no converge con 2 - 102
# La combinación relu - invscaling - sgd converge con 2 - 102
# La combinación relu - invscaling - adam converge con 2 - 102
# La combinación relu - adaptive - lbfgs no converge con 2 - 102
# La combinación relu - adaptive - sgd no converge con 2 - 102
# La combinación relu - adaptive - adam converge con 2 - 102
# La combinación identity - constant - lbfgs no converge con 2 - 102
# La combinación identity - constant - sgd no converge con 2 - 102
# La combinación identity - constant - adam converge con 2 - 102
# La combinación identity - invscaling - lbfgs no converge con 2 - 102
# La combinación identity - invscaling - sgd converge con 2 - 102
# La combinación identity - invscaling - adam converge con 2 - 102
# La combinación identity - adaptive - lbfgs converge con 2 - 102
# La combinación identity - adaptive - sgd no converge con 2 - 102
# La combinación identity - adaptive - adam converge con 2 - 102
# La combinación logistic - constant - lbfgs converge con 2 - 102
# La combinación logistic - constant - sgd converge con 2 - 102
# La combinación logistic - constant - adam converge con 2 - 102
# La combinación logistic - invscaling - lbfgs converge con 2 - 102
# La combinación logistic - invscaling - sgd converge con 2 - 102
# La combinación logistic - invscaling - adam converge con 2 - 102
# La combinación logistic - adaptive - lbfgs converge con 2 - 102
# La combinación logistic - adaptive - sgd converge con 2 - 102
# La combinación logistic - adaptive - adam converge con 2 - 102
# La combinación tanh - constant - lbfgs no converge con 2 - 102
# La combinación tanh - constant - sgd no converge con 2 - 102
# La combinación tanh - constant - adam converge con 2 - 102
# La combinación tanh - invscaling - lbfgs no converge con 2 - 102
# La combinación tanh - invscaling - sgd converge con 2 - 102
# La combinación tanh - invscaling - adam converge con 2 - 102
# La combinación tanh - adaptive - lbfgs no converge con 2 - 102
# La combinación tanh - adaptive - sgd no converge con 2 - 102
# La combinación tanh - adaptive - adam converge con 2 - 102
# La combinación relu - constant - lbfgs no converge con 2 - 102
# La combinación relu - constant - sgd no converge con 2 - 102
# La combinación relu - constant - adam no converge con 2 - 102
# La combinación relu - invscaling - lbfgs no converge con 2 - 102
# La combinación relu - invscaling - sgd converge con 2 - 102
# La combinación relu - invscaling - adam converge con 2 - 102
# La combinación relu - adaptive - lbfgs converge con 2 - 102
# La combinación relu - adaptive - sgd converge con 2 - 102
# La combinación relu - adaptive - adam converge con 2 - 102
# La combinación identity - constant - lbfgs converge con 2 - 102
# La combinación identity - constant - sgd no converge con 2 - 102
# La combinación identity - constant - adam converge con 2 - 102
# La combinación identity - invscaling - lbfgs converge con 2 - 102
# La combinación identity - invscaling - sgd converge con 2 - 102
# La combinación identity - invscaling - adam converge con 2 - 102
# La combinación identity - adaptive - lbfgs no converge con 2 - 102
# La combinación identity - adaptive - sgd no converge con 2 - 102
# La combinación identity - adaptive - adam converge con 2 - 102
# La combinación logistic - constant - lbfgs converge con 2 - 102
# La combinación logistic - constant - sgd converge con 2 - 102
# La combinación logistic - constant - adam converge con 2 - 102
# La combinación logistic - invscaling - lbfgs converge con 2 - 102
# La combinación logistic - invscaling - sgd converge con 2 - 102
# La combinación logistic - invscaling - adam no converge con 2 - 102
# La combinación logistic - adaptive - lbfgs converge con 2 - 102
# La combinación logistic - adaptive - sgd converge con 2 - 102
# La combinación logistic - adaptive - adam converge con 2 - 102
# La combinación tanh - constant - lbfgs no converge con 2 - 102
# La combinación tanh - constant - sgd no converge con 2 - 102
# La combinación tanh - constant - adam converge con 2 - 102
# La combinación tanh - invscaling - lbfgs no converge con 2 - 102
# La combinación tanh - invscaling - sgd converge con 2 - 102
# La combinación tanh - invscaling - adam converge con 2 - 102
# La combinación tanh - adaptive - lbfgs no converge con 2 - 102
# La combinación tanh - adaptive - sgd no converge con 2 - 102
# La combinación tanh - adaptive - adam converge con 2 - 102
# La combinación relu - constant - lbfgs converge con 2 - 102
# La combinación relu - constant - sgd no converge con 2 - 102
# La combinación relu - constant - adam converge con 2 - 102
# La combinación relu - invscaling - lbfgs converge con 2 - 102
# La combinación relu - invscaling - sgd converge con 2 - 102
# La combinación relu - invscaling - adam converge con 2 - 102
# La combinación relu - adaptive - lbfgs converge con 2 - 102
# La combinación relu - adaptive - sgd converge con 2 - 102
# La combinación relu - adaptive - adam converge con 2 - 102
# La combinación identity - constant - lbfgs converge con 52 - 2
# La combinación identity - constant - sgd no converge con 52 - 2
# La combinación identity - constant - adam converge con 52 - 2
# La combinación identity - invscaling - lbfgs no converge con 52 - 2
# La combinación identity - invscaling - sgd converge con 52 - 2
# La combinación identity - invscaling - adam converge con 52 - 2
# La combinación identity - adaptive - lbfgs converge con 52 - 2
# La combinación identity - adaptive - sgd no converge con 52 - 2
# La combinación identity - adaptive - adam converge con 52 - 2
# La combinación logistic - constant - lbfgs no converge con 52 - 2
# La combinación logistic - constant - sgd converge con 52 - 2
# La combinación logistic - constant - adam no converge con 52 - 2
# La combinación logistic - invscaling - lbfgs converge con 52 - 2
# La combinación logistic - invscaling - sgd converge con 52 - 2
# La combinación logistic - invscaling - adam no converge con 52 - 2
# La combinación logistic - adaptive - lbfgs converge con 52 - 2
# La combinación logistic - adaptive - sgd converge con 52 - 2
# La combinación logistic - adaptive - adam no converge con 52 - 2
# La combinación tanh - constant - lbfgs no converge con 52 - 2
# La combinación tanh - constant - sgd no converge con 52 - 2
# La combinación tanh - constant - adam converge con 52 - 2
# La combinación tanh - invscaling - lbfgs no converge con 52 - 2
# La combinación tanh - invscaling - sgd converge con 52 - 2
# La combinación tanh - invscaling - adam converge con 52 - 2
# La combinación tanh - adaptive - lbfgs no converge con 52 - 2
# La combinación tanh - adaptive - sgd no converge con 52 - 2
# La combinación tanh - adaptive - adam no converge con 52 - 2
# La combinación relu - constant - lbfgs converge con 52 - 2
# La combinación relu - constant - sgd converge con 52 - 2
# La combinación relu - constant - adam converge con 52 - 2
# La combinación relu - invscaling - lbfgs converge con 52 - 2
# La combinación relu - invscaling - sgd converge con 52 - 2
# La combinación relu - invscaling - adam no converge con 52 - 2
# La combinación relu - adaptive - lbfgs converge con 52 - 2
# La combinación relu - adaptive - sgd converge con 52 - 2
# La combinación relu - adaptive - adam no converge con 52 - 2
# La combinación identity - constant - lbfgs converge con 52 - 2
# La combinación identity - constant - sgd no converge con 52 - 2
# La combinación identity - constant - adam converge con 52 - 2
# La combinación identity - invscaling - lbfgs converge con 52 - 2
# La combinación identity - invscaling - sgd converge con 52 - 2
# La combinación identity - invscaling - adam converge con 52 - 2
# La combinación identity - adaptive - lbfgs converge con 52 - 2
# La combinación identity - adaptive - sgd no converge con 52 - 2
# La combinación identity - adaptive - adam converge con 52 - 2
# La combinación logistic - constant - lbfgs converge con 52 - 2
# La combinación logistic - constant - sgd converge con 52 - 2
# La combinación logistic - constant - adam no converge con 52 - 2
# La combinación logistic - invscaling - lbfgs converge con 52 - 2
# La combinación logistic - invscaling - sgd converge con 52 - 2
# La combinación logistic - invscaling - adam converge con 52 - 2
# La combinación logistic - adaptive - lbfgs converge con 52 - 2
# La combinación logistic - adaptive - sgd converge con 52 - 2
# La combinación logistic - adaptive - adam converge con 52 - 2
# La combinación tanh - constant - lbfgs no converge con 52 - 2
# La combinación tanh - constant - sgd no converge con 52 - 2
# La combinación tanh - constant - adam converge con 52 - 2
# La combinación tanh - invscaling - lbfgs no converge con 52 - 2
# La combinación tanh - invscaling - sgd converge con 52 - 2
# La combinación tanh - invscaling - adam converge con 52 - 2
# La combinación tanh - adaptive - lbfgs no converge con 52 - 2
# La combinación tanh - adaptive - sgd no converge con 52 - 2
# La combinación tanh - adaptive - adam converge con 52 - 2
# La combinación relu - constant - lbfgs no converge con 52 - 2
# La combinación relu - constant - sgd no converge con 52 - 2
# La combinación relu - constant - adam no converge con 52 - 2
# La combinación relu - invscaling - lbfgs converge con 52 - 2
# La combinación relu - invscaling - sgd converge con 52 - 2
# La combinación relu - invscaling - adam no converge con 52 - 2
# La combinación relu - adaptive - lbfgs no converge con 52 - 2
# La combinación relu - adaptive - sgd no converge con 52 - 2
# La combinación relu - adaptive - adam converge con 52 - 2
# La combinación identity - constant - lbfgs converge con 52 - 2
# La combinación identity - constant - sgd no converge con 52 - 2
# La combinación identity - constant - adam converge con 52 - 2
# La combinación identity - invscaling - lbfgs converge con 52 - 2
# La combinación identity - invscaling - sgd converge con 52 - 2
# La combinación identity - invscaling - adam converge con 52 - 2
# La combinación identity - adaptive - lbfgs converge con 52 - 2
# La combinación identity - adaptive - sgd no converge con 52 - 2
# La combinación identity - adaptive - adam converge con 52 - 2
# La combinación logistic - constant - lbfgs converge con 52 - 2
# La combinación logistic - constant - sgd converge con 52 - 2
# La combinación logistic - constant - adam converge con 52 - 2
# La combinación logistic - invscaling - lbfgs converge con 52 - 2
# La combinación logistic - invscaling - sgd converge con 52 - 2
# La combinación logistic - invscaling - adam converge con 52 - 2
# La combinación logistic - adaptive - lbfgs converge con 52 - 2
# La combinación logistic - adaptive - sgd converge con 52 - 2
# La combinación logistic - adaptive - adam converge con 52 - 2
# La combinación tanh - constant - lbfgs no converge con 52 - 2
# La combinación tanh - constant - sgd no converge con 52 - 2
# La combinación tanh - constant - adam converge con 52 - 2
# La combinación tanh - invscaling - lbfgs no converge con 52 - 2
# La combinación tanh - invscaling - sgd converge con 52 - 2
# La combinación tanh - invscaling - adam converge con 52 - 2
# La combinación tanh - adaptive - lbfgs no converge con 52 - 2
# La combinación tanh - adaptive - sgd no converge con 52 - 2
# La combinación tanh - adaptive - adam converge con 52 - 2
# La combinación relu - constant - lbfgs no converge con 52 - 2
# La combinación relu - constant - sgd no converge con 52 - 2
# La combinación relu - constant - adam converge con 52 - 2
# La combinación relu - invscaling - lbfgs converge con 52 - 2
# La combinación relu - invscaling - sgd converge con 52 - 2
# La combinación relu - invscaling - adam no converge con 52 - 2
# La combinación relu - adaptive - lbfgs no converge con 52 - 2
# La combinación relu - adaptive - sgd converge con 52 - 2
# La combinación relu - adaptive - adam no converge con 52 - 2
# La combinación identity - constant - lbfgs no converge con 52 - 2
# La combinación identity - constant - sgd no converge con 52 - 2
# La combinación identity - constant - adam converge con 52 - 2
# La combinación identity - invscaling - lbfgs converge con 52 - 2
# La combinación identity - invscaling - sgd converge con 52 - 2
# La combinación identity - invscaling - adam converge con 52 - 2
# La combinación identity - adaptive - lbfgs no converge con 52 - 2
# La combinación identity - adaptive - sgd no converge con 52 - 2
# La combinación identity - adaptive - adam converge con 52 - 2
# La combinación logistic - constant - lbfgs converge con 52 - 2
# La combinación logistic - constant - sgd converge con 52 - 2
# La combinación logistic - constant - adam converge con 52 - 2
# La combinación logistic - invscaling - lbfgs converge con 52 - 2
# La combinación logistic - invscaling - sgd converge con 52 - 2
# La combinación logistic - invscaling - adam converge con 52 - 2
# La combinación logistic - adaptive - lbfgs converge con 52 - 2
# La combinación logistic - adaptive - sgd converge con 52 - 2
# La combinación logistic - adaptive - adam no converge con 52 - 2
# La combinación tanh - constant - lbfgs no converge con 52 - 2
# La combinación tanh - constant - sgd no converge con 52 - 2
# La combinación tanh - constant - adam converge con 52 - 2
# La combinación tanh - invscaling - lbfgs no converge con 52 - 2
# La combinación tanh - invscaling - sgd converge con 52 - 2
# La combinación tanh - invscaling - adam converge con 52 - 2
# La combinación tanh - adaptive - lbfgs no converge con 52 - 2
# La combinación tanh - adaptive - sgd no converge con 52 - 2
# La combinación tanh - adaptive - adam converge con 52 - 2
# La combinación relu - constant - lbfgs no converge con 52 - 2
# La combinación relu - constant - sgd no converge con 52 - 2
# La combinación relu - constant - adam no converge con 52 - 2
# La combinación relu - invscaling - lbfgs converge con 52 - 2
# La combinación relu - invscaling - sgd converge con 52 - 2
# La combinación relu - invscaling - adam no converge con 52 - 2
# La combinación relu - adaptive - lbfgs no converge con 52 - 2
# La combinación relu - adaptive - sgd no converge con 52 - 2
# La combinación relu - adaptive - adam no converge con 52 - 2
# La combinación identity - constant - lbfgs converge con 52 - 2
# La combinación identity - constant - sgd no converge con 52 - 2
# La combinación identity - constant - adam converge con 52 - 2
# La combinación identity - invscaling - lbfgs converge con 52 - 2
# La combinación identity - invscaling - sgd converge con 52 - 2
# La combinación identity - invscaling - adam converge con 52 - 2
# La combinación identity - adaptive - lbfgs converge con 52 - 2
# La combinación identity - adaptive - sgd no converge con 52 - 2
# La combinación identity - adaptive - adam converge con 52 - 2
# La combinación logistic - constant - lbfgs converge con 52 - 2
# La combinación logistic - constant - sgd converge con 52 - 2
# La combinación logistic - constant - adam converge con 52 - 2
# La combinación logistic - invscaling - lbfgs converge con 52 - 2
# La combinación logistic - invscaling - sgd converge con 52 - 2
# La combinación logistic - invscaling - adam converge con 52 - 2
# La combinación logistic - adaptive - lbfgs converge con 52 - 2
# La combinación logistic - adaptive - sgd converge con 52 - 2
# La combinación logistic - adaptive - adam converge con 52 - 2
# La combinación tanh - constant - lbfgs no converge con 52 - 2
# La combinación tanh - constant - sgd converge con 52 - 2
# La combinación tanh - constant - adam converge con 52 - 2
# La combinación tanh - invscaling - lbfgs no converge con 52 - 2
# La combinación tanh - invscaling - sgd converge con 52 - 2
# La combinación tanh - invscaling - adam converge con 52 - 2
# La combinación tanh - adaptive - lbfgs no converge con 52 - 2
# La combinación tanh - adaptive - sgd no converge con 52 - 2
# La combinación tanh - adaptive - adam converge con 52 - 2
# La combinación relu - constant - lbfgs no converge con 52 - 2
# La combinación relu - constant - sgd no converge con 52 - 2
# La combinación relu - constant - adam no converge con 52 - 2
# La combinación relu - invscaling - lbfgs no converge con 52 - 2
# La combinación relu - invscaling - sgd converge con 52 - 2
# La combinación relu - invscaling - adam no converge con 52 - 2
# La combinación relu - adaptive - lbfgs no converge con 52 - 2
# La combinación relu - adaptive - sgd no converge con 52 - 2
# La combinación relu - adaptive - adam no converge con 52 - 2
# La combinación identity - constant - lbfgs converge con 52 - 52
# La combinación identity - constant - sgd no converge con 52 - 52
# La combinación identity - constant - adam converge con 52 - 52
# La combinación identity - invscaling - lbfgs converge con 52 - 52
# La combinación identity - invscaling - sgd converge con 52 - 52
# La combinación identity - invscaling - adam converge con 52 - 52
# La combinación identity - adaptive - lbfgs converge con 52 - 52
# La combinación identity - adaptive - sgd no converge con 52 - 52
# La combinación identity - adaptive - adam converge con 52 - 52
# La combinación logistic - constant - lbfgs converge con 52 - 52
# La combinación logistic - constant - sgd converge con 52 - 52
# La combinación logistic - constant - adam converge con 52 - 52
# La combinación logistic - invscaling - lbfgs converge con 52 - 52
# La combinación logistic - invscaling - sgd converge con 52 - 52
# La combinación logistic - invscaling - adam no converge con 52 - 52
# La combinación logistic - adaptive - lbfgs converge con 52 - 52
# La combinación logistic - adaptive - sgd converge con 52 - 52
# La combinación logistic - adaptive - adam no converge con 52 - 52
# La combinación tanh - constant - lbfgs no converge con 52 - 52
# La combinación tanh - constant - sgd no converge con 52 - 52
# La combinación tanh - constant - adam converge con 52 - 52
# La combinación tanh - invscaling - lbfgs no converge con 52 - 52
# La combinación tanh - invscaling - sgd converge con 52 - 52
# La combinación tanh - invscaling - adam converge con 52 - 52
# La combinación tanh - adaptive - lbfgs no converge con 52 - 52
# La combinación tanh - adaptive - sgd no converge con 52 - 52
# La combinación tanh - adaptive - adam converge con 52 - 52
# La combinación relu - constant - lbfgs converge con 52 - 52
# La combinación relu - constant - sgd no converge con 52 - 52
# La combinación relu - constant - adam no converge con 52 - 52
# La combinación relu - invscaling - lbfgs converge con 52 - 52
# La combinación relu - invscaling - sgd converge con 52 - 52
# La combinación relu - invscaling - adam converge con 52 - 52
# La combinación relu - adaptive - lbfgs converge con 52 - 52
# La combinación relu - adaptive - sgd converge con 52 - 52
# La combinación relu - adaptive - adam no converge con 52 - 52
# La combinación identity - constant - lbfgs converge con 52 - 52
# La combinación identity - constant - sgd no converge con 52 - 52
# La combinación identity - constant - adam converge con 52 - 52
# La combinación identity - invscaling - lbfgs converge con 52 - 52
# La combinación identity - invscaling - sgd converge con 52 - 52
# La combinación identity - invscaling - adam converge con 52 - 52
# La combinación identity - adaptive - lbfgs no converge con 52 - 52
# La combinación identity - adaptive - sgd no converge con 52 - 52
# La combinación identity - adaptive - adam converge con 52 - 52
# La combinación logistic - constant - lbfgs converge con 52 - 52
# La combinación logistic - constant - sgd converge con 52 - 52
# La combinación logistic - constant - adam converge con 52 - 52
# La combinación logistic - invscaling - lbfgs converge con 52 - 52
# La combinación logistic - invscaling - sgd converge con 52 - 52
# La combinación logistic - invscaling - adam converge con 52 - 52
# La combinación logistic - adaptive - lbfgs converge con 52 - 52
# La combinación logistic - adaptive - sgd converge con 52 - 52
# La combinación logistic - adaptive - adam converge con 52 - 52
# La combinación tanh - constant - lbfgs no converge con 52 - 52
# La combinación tanh - constant - sgd no converge con 52 - 52
# ...
# La combinación identity - invscaling - adam converge con 202 - 52
# La combinación identity - adaptive - lbfgs converge con 202 - 52
# La combinación identity - adaptive - sgd no converge con 202 - 52
# La combinación identity - adaptive - adam converge con 202 - 52
# La combinación logistic - constant - lbfgs converge con 202 - 52
# La combinación logistic - constant - sgd converge con 202 - 52
# La combinación logistic - constant - adam converge con 202 - 52
# La combinación logistic - invscaling - lbfgs converge con 202 - 52
# La combinación logistic - invscaling - sgd converge con 202 - 52
# La combinación logistic - invscaling - adam converge con 202 - 52
# La combinación logistic - adaptive - lbfgs converge con 202 - 52
# La combinación logistic - adaptive - sgd converge con 202 - 52
# La combinación logistic - adaptive - adam converge con 202 - 52
# La combinación tanh - constant - lbfgs no converge con 202 - 52
# La combinación tanh - constant - sgd no converge con 202 - 52
# La combinación tanh - constant - adam converge con 202 - 52
# La combinación tanh - invscaling - lbfgs no converge con 202 - 52
# La combinación tanh - invscaling - sgd converge con 202 - 52
# La combinación tanh - invscaling - adam no converge con 202 - 52
# La combinación tanh - adaptive - lbfgs no converge con 202 - 52
# La combinación tanh - adaptive - sgd no converge con 202 - 52
# La combinación tanh - adaptive - adam no converge con 202 - 52
# La combinación relu - constant - lbfgs converge con 202 - 52
# La combinación relu - constant - sgd no converge con 202 - 52
# La combinación relu - constant - adam no converge con 202 - 52
# La combinación relu - invscaling - lbfgs no converge con 202 - 52
# La combinación relu - invscaling - sgd converge con 202 - 52
# La combinación relu - invscaling - adam converge con 202 - 52
# La combinación relu - adaptive - lbfgs converge con 202 - 52
# La combinación relu - adaptive - sgd no converge con 202 - 52
# La combinación relu - adaptive - adam converge con 202 - 52
# La combinación identity - constant - lbfgs converge con 202 - 52
# La combinación identity - constant - sgd no converge con 202 - 52
# La combinación identity - constant - adam converge con 202 - 52
# La combinación identity - invscaling - lbfgs converge con 202 - 52
# La combinación identity - invscaling - sgd converge con 202 - 52
# La combinación identity - invscaling - adam converge con 202 - 52
# La combinación identity - adaptive - lbfgs converge con 202 - 52
# La combinación identity - adaptive - sgd no converge con 202 - 52
# La combinación identity - adaptive - adam converge con 202 - 52
# La combinación logistic - constant - lbfgs converge con 202 - 52
# La combinación logistic - constant - sgd converge con 202 - 52
# La combinación logistic - constant - adam converge con 202 - 52
# La combinación logistic - invscaling - lbfgs converge con 202 - 52
# La combinación logistic - invscaling - sgd converge con 202 - 52
# La combinación logistic - invscaling - adam converge con 202 - 52
# La combinación logistic - adaptive - lbfgs converge con 202 - 52
# La combinación logistic - adaptive - sgd converge con 202 - 52
# La combinación logistic - adaptive - adam converge con 202 - 52
# La combinación tanh - constant - lbfgs no converge con 202 - 52
# La combinación tanh - constant - sgd no converge con 202 - 52
# La combinación tanh - constant - adam no converge con 202 - 52
# La combinación tanh - invscaling - lbfgs no converge con 202 - 52
# La combinación tanh - invscaling - sgd converge con 202 - 52
# La combinación tanh - invscaling - adam no converge con 202 - 52
# La combinación tanh - adaptive - lbfgs no converge con 202 - 52
# La combinación tanh - adaptive - sgd no converge con 202 - 52
# La combinación tanh - adaptive - adam no converge con 202 - 52
# La combinación relu - constant - lbfgs no converge con 202 - 52
# La combinación relu - constant - sgd no converge con 202 - 52
# La combinación relu - constant - adam no converge con 202 - 52
# La combinación relu - invscaling - lbfgs no converge con 202 - 52
# La combinación relu - invscaling - sgd converge con 202 - 52
# La combinación relu - invscaling - adam no converge con 202 - 52
# La combinación relu - adaptive - lbfgs no converge con 202 - 52
# La combinación relu - adaptive - sgd no converge con 202 - 52
# La combinación relu - adaptive - adam no converge con 202 - 52
# La combinación identity - constant - lbfgs converge con 202 - 102
# La combinación identity - constant - sgd no converge con 202 - 102
# La combinación identity - constant - adam converge con 202 - 102
# La combinación identity - invscaling - lbfgs converge con 202 - 102
# La combinación identity - invscaling - sgd converge con 202 - 102
# La combinación identity - invscaling - adam converge con 202 - 102
# La combinación identity - adaptive - lbfgs converge con 202 - 102
# La combinación identity - adaptive - sgd no converge con 202 - 102
# La combinación identity - adaptive - adam converge con 202 - 102
# La combinación logistic - constant - lbfgs converge con 202 - 102
# La combinación logistic - constant - sgd converge con 202 - 102
# La combinación logistic - constant - adam converge con 202 - 102
# La combinación logistic - invscaling - lbfgs no converge con 202 - 102
# La combinación logistic - invscaling - sgd converge con 202 - 102
# La combinación logistic - invscaling - adam converge con 202 - 102
# La combinación logistic - adaptive - lbfgs converge con 202 - 102
# La combinación logistic - adaptive - sgd converge con 202 - 102
# La combinación logistic - adaptive - adam converge con 202 - 102
# La combinación tanh - constant - lbfgs no converge con 202 - 102
# La combinación tanh - constant - sgd no converge con 202 - 102
# La combinación tanh - constant - adam no converge con 202 - 102
# La combinación tanh - invscaling - lbfgs no converge con 202 - 102
# La combinación tanh - invscaling - sgd converge con 202 - 102
# La combinación tanh - invscaling - adam no converge con 202 - 102
# La combinación tanh - adaptive - lbfgs no converge con 202 - 102
# La combinación tanh - adaptive - sgd no converge con 202 - 102
# La combinación tanh - adaptive - adam converge con 202 - 102
# La combinación relu - constant - lbfgs no converge con 202 - 102
# La combinación relu - constant - sgd no converge con 202 - 102
# La combinación relu - constant - adam converge con 202 - 102
# La combinación relu - invscaling - lbfgs no converge con 202 - 102
# La combinación relu - invscaling - sgd converge con 202 - 102
# La combinación relu - invscaling - adam converge con 202 - 102
# La combinación relu - adaptive - lbfgs converge con 202 - 102
# La combinación relu - adaptive - sgd no converge con 202 - 102
# La combinación relu - adaptive - adam no converge con 202 - 102
# La combinación identity - constant - lbfgs converge con 202 - 102
# La combinación identity - constant - sgd no converge con 202 - 102
# La combinación identity - constant - adam converge con 202 - 102
# La combinación identity - invscaling - lbfgs converge con 202 - 102
# La combinación identity - invscaling - sgd converge con 202 - 102
# La combinación identity - invscaling - adam converge con 202 - 102
# La combinación identity - adaptive - lbfgs converge con 202 - 102
# La combinación identity - adaptive - sgd no converge con 202 - 102
# La combinación identity - adaptive - adam converge con 202 - 102
# La combinación logistic - constant - lbfgs converge con 202 - 102
# La combinación logistic - constant - sgd converge con 202 - 102
# La combinación logistic - constant - adam converge con 202 - 102
# La combinación logistic - invscaling - lbfgs converge con 202 - 102
# La combinación logistic - invscaling - sgd converge con 202 - 102
# La combinación logistic - invscaling - adam converge con 202 - 102
# La combinación logistic - adaptive - lbfgs converge con 202 - 102
# La combinación logistic - adaptive - sgd converge con 202 - 102
# La combinación logistic - adaptive - adam converge con 202 - 102
# La combinación tanh - constant - lbfgs no converge con 202 - 102
# La combinación tanh - constant - sgd no converge con 202 - 102
# La combinación tanh - constant - adam converge con 202 - 102
# La combinación tanh - invscaling - lbfgs no converge con 202 - 102
# La combinación tanh - invscaling - sgd converge con 202 - 102
# La combinación tanh - invscaling - adam no converge con 202 - 102
# La combinación tanh - adaptive - lbfgs no converge con 202 - 102
# La combinación tanh - adaptive - sgd no converge con 202 - 102
# La combinación tanh - adaptive - adam converge con 202 - 102
# La combinación relu - constant - lbfgs no converge con 202 - 102
# La combinación relu - constant - sgd no converge con 202 - 102
# La combinación relu - constant - adam no converge con 202 - 102
# La combinación relu - invscaling - lbfgs no converge con 202 - 102
# La combinación relu - invscaling - sgd converge con 202 - 102
# La combinación relu - invscaling - adam no converge con 202 - 102
# La combinación relu - adaptive - lbfgs converge con 202 - 102
# La combinación relu - adaptive - sgd no converge con 202 - 102
# La combinación relu - adaptive - adam no converge con 202 - 102
# La combinación identity - constant - lbfgs converge con 202 - 102
# La combinación identity - constant - sgd no converge con 202 - 102
# La combinación identity - constant - adam converge con 202 - 102
# La combinación identity - invscaling - lbfgs converge con 202 - 102
# La combinación identity - invscaling - sgd converge con 202 - 102
# La combinación identity - invscaling - adam converge con 202 - 102
# La combinación identity - adaptive - lbfgs converge con 202 - 102
# La combinación identity - adaptive - sgd no converge con 202 - 102
# La combinación identity - adaptive - adam converge con 202 - 102
# La combinación logistic - constant - lbfgs converge con 202 - 102
# La combinación logistic - constant - sgd converge con 202 - 102
# La combinación logistic - constant - adam converge con 202 - 102
# La combinación logistic - invscaling - lbfgs converge con 202 - 102
# La combinación logistic - invscaling - sgd converge con 202 - 102
# La combinación logistic - invscaling - adam converge con 202 - 102
# La combinación logistic - adaptive - lbfgs converge con 202 - 102
# La combinación logistic - adaptive - sgd converge con 202 - 102
# La combinación logistic - adaptive - adam converge con 202 - 102
# La combinación tanh - constant - lbfgs no converge con 202 - 102
# La combinación tanh - constant - sgd converge con 202 - 102
# La combinación tanh - constant - adam no converge con 202 - 102
# La combinación tanh - invscaling - lbfgs no converge con 202 - 102
# La combinación tanh - invscaling - sgd converge con 202 - 102
# La combinación tanh - invscaling - adam no converge con 202 - 102
# La combinación tanh - adaptive - lbfgs no converge con 202 - 102
# La combinación tanh - adaptive - sgd no converge con 202 - 102
# La combinación tanh - adaptive - adam no converge con 202 - 102
# La combinación relu - constant - lbfgs converge con 202 - 102
# La combinación relu - constant - sgd no converge con 202 - 102
# La combinación relu - constant - adam no converge con 202 - 102
# La combinación relu - invscaling - lbfgs converge con 202 - 102
# La combinación relu - invscaling - sgd converge con 202 - 102
# La combinación relu - invscaling - adam no converge con 202 - 102
# La combinación relu - adaptive - lbfgs no converge con 202 - 102
# La combinación relu - adaptive - sgd no converge con 202 - 102
# La combinación relu - adaptive - adam no converge con 202 - 102
# La combinación identity - constant - lbfgs converge con 202 - 102
# La combinación identity - constant - sgd converge con 202 - 102
# La combinación identity - constant - adam converge con 202 - 102
# La combinación identity - invscaling - lbfgs converge con 202 - 102
# La combinación identity - invscaling - sgd converge con 202 - 102
# La combinación identity - invscaling - adam converge con 202 - 102
# La combinación identity - adaptive - lbfgs converge con 202 - 102
# La combinación identity - adaptive - sgd no converge con 202 - 102
# La combinación identity - adaptive - adam converge con 202 - 102
# La combinación logistic - constant - lbfgs converge con 202 - 102
# La combinación logistic - constant - sgd converge con 202 - 102
# La combinación logistic - constant - adam converge con 202 - 102
# La combinación logistic - invscaling - lbfgs converge con 202 - 102
# La combinación logistic - invscaling - sgd converge con 202 - 102
# La combinación logistic - invscaling - adam converge con 202 - 102
# La combinación logistic - adaptive - lbfgs converge con 202 - 102
# La combinación logistic - adaptive - sgd converge con 202 - 102
# La combinación logistic - adaptive - adam converge con 202 - 102
# La combinación tanh - constant - lbfgs no converge con 202 - 102
# La combinación tanh - constant - sgd converge con 202 - 102
# La combinación tanh - constant - adam no converge con 202 - 102
# La combinación tanh - invscaling - lbfgs no converge con 202 - 102
# La combinación tanh - invscaling - sgd converge con 202 - 102
# La combinación tanh - invscaling - adam no converge con 202 - 102
# La combinación tanh - adaptive - lbfgs no converge con 202 - 102
# La combinación tanh - adaptive - sgd no converge con 202 - 102
# La combinación tanh - adaptive - adam converge con 202 - 102
# La combinación relu - constant - lbfgs no converge con 202 - 102
# La combinación relu - constant - sgd no converge con 202 - 102
# La combinación relu - constant - adam converge con 202 - 102
# La combinación relu - invscaling - lbfgs converge con 202 - 102
# La combinación relu - invscaling - sgd converge con 202 - 102
# La combinación relu - invscaling - adam no converge con 202 - 102
# La combinación relu - adaptive - lbfgs no converge con 202 - 102
# La combinación relu - adaptive - sgd no converge con 202 - 102
# La combinación relu - adaptive - adam no converge con 202 - 102
# La combinación identity - constant - lbfgs converge con 202 - 102
# La combinación identity - constant - sgd no converge con 202 - 102
# La combinación identity - constant - adam converge con 202 - 102
# La combinación identity - invscaling - lbfgs converge con 202 - 102
# La combinación identity - invscaling - sgd converge con 202 - 102
# La combinación identity - invscaling - adam converge con 202 - 102
# La combinación identity - adaptive - lbfgs converge con 202 - 102
# La combinación identity - adaptive - sgd no converge con 202 - 102
# La combinación identity - adaptive - adam converge con 202 - 102
# La combinación logistic - constant - lbfgs converge con 202 - 102
# La combinación logistic - constant - sgd converge con 202 - 102
# La combinación logistic - constant - adam converge con 202 - 102
# La combinación logistic - invscaling - lbfgs converge con 202 - 102
# La combinación logistic - invscaling - sgd converge con 202 - 102
# La combinación logistic - invscaling - adam converge con 202 - 102
# La combinación logistic - adaptive - lbfgs converge con 202 - 102
# La combinación logistic - adaptive - sgd converge con 202 - 102
# La combinación logistic - adaptive - adam converge con 202 - 102
# La combinación tanh - constant - lbfgs no converge con 202 - 102
# La combinación tanh - constant - sgd no converge con 202 - 102
# La combinación tanh - constant - adam no converge con 202 - 102
# La combinación tanh - invscaling - lbfgs no converge con 202 - 102
# La combinación tanh - invscaling - sgd converge con 202 - 102
# La combinación tanh - invscaling - adam no converge con 202 - 102
# La combinación tanh - adaptive - lbfgs no converge con 202 - 102
# La combinación tanh - adaptive - sgd no converge con 202 - 102
# La combinación tanh - adaptive - adam no converge con 202 - 102
# La combinación relu - constant - lbfgs converge con 202 - 102
# La combinación relu - constant - sgd no converge con 202 - 102
# La combinación relu - constant - adam no converge con 202 - 102
# La combinación relu - invscaling - lbfgs converge con 202 - 102
# La combinación relu - invscaling - sgd converge con 202 - 102
# La combinación relu - invscaling - adam no converge con 202 - 102
# La combinación relu - adaptive - lbfgs converge con 202 - 102
# La combinación relu - adaptive - sgd no converge con 202 - 102
# La combinación relu - adaptive - adam no converge con 202 - 102

# %% [markdown]
# A continuación se presenta la tabla con los resultados para el mejores score resultante en la validación de las redes de la tercera capa escondida.

# %%
resul3 = pd.DataFrame(data=top_5, columns=['score','N', 'Función de Activación', 'Tasa de aprendizaje', 'Algoritmo'])
resul3 = resul3.sort_values(by=['score'], ascending=False)
resul3.head()
# Out:
#          score    N Función de Activación Tasa de aprendizaje Algoritmo
# 1508  0.862275  202                  relu          invscaling      adam
# 1510  0.862275  202                  relu            adaptive      adam
# 1612  0.862275  202                  relu            constant      adam
# 1121  0.860778  152                  relu            constant      adam
# 864   0.860778  102                  relu            adaptive      adam

# %% [markdown]
# Para una mejor visualización del comportamiento de cada uno de los parámetros estudiados, se presenta la siguiente gráfica que resume los resultados obtenidos para el caso en el que se usa el algoritmo "sgd" y el algoritmo "adam".

# %%
f = plt.figure(figsize=(18,6))
f.suptitle('Comparación de los parámetros seleccionados teniendo en cuenta los algoritmos en la tercera capa escondida', y=1.2, fontsize=16)

plot_args = [{'c': 'blue', 'linestyle': '-'},
             {'c': 'orange', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'red', 'linestyle': '-'},
             {'c': 'olive', 'linestyle': '-'},
             {'c': 'magenta', 'linestyle': '-'},
             {'c': 'black', 'linestyle': '--'},
             {'c': 'yellowgreen', 'linestyle': '--'},
             {'c': 'violet', 'linestyle': '--'},
             {'c': 'tomato', 'linestyle': '--'},
             {'c': 'navy', 'linestyle': '--'},
             {'c': 'brown', 'linestyle': '--'}]

cont=1
args = 0
labels = []
for alg in algoritmo:
  ax = plt.subplot(2,2,cont)
  ax.set_title(r'$\bf{Algoritmo~}$'+r'$\bf{}$'.format(alg), fontsize=14)
  ax.set_ylabel('Score')
  ax.set_xlabel('Número de neuronas (N)')
  ax.grid(linestyle='--',b=True, which='major')
  for act in activacion:
    for rate in tasas_aprendizaje:
      temp = resul3.loc[(resul3['Función de Activación']==act) & (resul3['Tasa de aprendizaje']==rate) & (resul3['Algoritmo']==alg)]
      temp = temp.sort_values(by=['N'], ascending=True)
      ax.plot(temp['N'].values, temp['score'].values, **plot_args[args])
      labels.append(r'$\bf{act:}$ ' + act + ' + ' + r'$\bf{tasa:}$ ' + rate)
      if args < 11:
        args = args + 1
      else:
        args = 0

  f.legend(ax.get_lines(), labels, ncol=3, loc="lower center", bbox_to_anchor=(0.4, 0.9))
  cont = cont+1

# %% [markdown]
# Teniendo en cuenta la combinación de parámetros con el porcentaje de precisión más alto, se procede a correr el modelo de perceptrón multinivel para los datos de prueba, el modelo de entrenamiento del clasificador es presentado a continuación.

# %%
# Se presentan los parámetros apropiados
N3 = resul3.iloc[0,:]['N'] # El número de neuronas apropiado obtenido previamente
activation = resul3.iloc[0,:]['Función de Activación'] # La función de activación
learning_rate = resul3.iloc[0,:]['Tasa de aprendizaje'] # Tasa de aprendizaje
algor = resul3.iloc[0,:]['Algoritmo'] # Algoritmo seleccionado

MLP_3L = MLPClassifier(hidden_layer_sizes=(N,N2,N3,),activation=activation, learning_rate=learning_rate, solver=algor,max_iter=1200)
Hidden_3L = MLP_3L.fit(x_train, y_train)

# %% [markdown]
# La precisión del modelo seleccionado es evaluada en la siguiente entrada de código.

# %%
result_3L = Hidden_3L.score(x_test, y_test)
print('El modelo con dos capas tiene una precisión del {:.2f}%'.format(result_3L*100))
# Out:
# El modelo con dos capas tiene una precisión del 83.89%

# %% [markdown]
# Para complementar la validación del modelo, se presenta la matriz de confusión, donde se puede detallar el porcentaje normalizado de los aciertos y desaciertos del modelo para cada una de las variables a clasificar. En este caso la diagonal corresponde al porcentaje normalizado del acierto de la predicción, mientras que los elementos fuera de la diagonal representan el porcentaje de desacierto para cada variable.

# %%
#y_pred = Hidden_1L.predict(x_test)
class_names = ['jazz and blues','soul and reggae']
plot_confusion_matrix(Hidden_3L, x_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues, normalize = 'true')
plt.title('Matriz de confusiones normalizada para el modelo de 3 capas escondidas', fontsize = 14)
plt.show()

# %% [markdown]
# ## Conclusiones
#
# En la siguiente tabla se resume el porcentaje de precisión de cada modelo implementado.

# %%
print('Modelo 1: MLP con 1 capa escondida \nModelo 2: MLP con 2 capas escondidas \nModelo 3: MLP con 3 capas escondidas \n')
medida =['Score']
results = {'Modelo 1': result_1L,
           'Modelo 2': result_2L,
           'Modelo 3': result_3L}
pd.DataFrame(results,medida,columns=['Modelo 1','Modelo 2', 'Modelo 3'])
# Out:
# Modelo 1: MLP con 1 capa escondida
# Modelo 2: MLP con 2 capas escondidas
# Modelo 3: MLP con 3 capas escondidas
#        Modelo 1  Modelo 2  Modelo 3
# Score  0.832934  0.852096  0.838922

# %%
best1l = resul1.iloc[0]
best2l = resul2.iloc[0]
best3l = resul3.iloc[0]

# %%
best1l
# Out:
# score                    0.831587
# N                             102
# Función de Activación        tanh
# Tasa de aprendizaje      adaptive
# Algoritmo                    adam
# Name: 42, dtype: object

# %%
best2l
# Out:
# score                    0.861527
# N                             202
# Función de Activación        relu
# Tasa de aprendizaje      adaptive
# Algoritmo                    adam
# Name: 414, dtype: object

# %%
best3l
# Out:
# score                      0.862275
# N                               202
# Función de Activación          relu
# Tasa de aprendizaje      invscaling
# Algoritmo                      adam
# Name: 1508, dtype: object

# %% [markdown]
# Se concluye así que el mejor modelo es el modelo con 2 capas escondidas. Por otra parte, cabe mencionar que el tiempo aproximado de ejecución de este notebook es de 132 minutos, aproximadamente.
